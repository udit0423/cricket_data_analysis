# %%
import pandas as pd

# %% [markdown]
# # Filter criteria: (typically for openers)
# # 1. Batting Average > 30
# # 2. Strike Rate > 140
# # 3. Innings Batted >= 3
# # 4. Boundary % > 50

# %%
file_path = "batting.csv"  
df = pd.read_csv(file_path)
print(df.head())
# Out:
#         batsmanName  runs  balls minutes  4s  6s      SR  \
# 0    Marcus Stoinis     0      1       -   0   0    0.00
# 1    Shikhar Dhawan    15     13       -   3   0  115.38
# 2    Ajinkya Rahane     2      4       -   0   0   50.00
# 3  Shreyas Iyer (c)    65     50       -   6   2  130.00
# 4    Rishabh Pant †    56     38       -   4   2  147.36
#
#                                          player_link   match_id
# 0  https://www.espncricinfo.com/cricketers/marcus...  scorecard
# 1  https://www.espncricinfo.com/cricketers/shikha...  scorecard
# 2  https://www.espncricinfo.com/cricketers/ajinky...  scorecard
# 3  https://www.espncricinfo.com/cricketers/shreya...  scorecard
# 4  https://www.espncricinfo.com/cricketers/rishab...  scorecard

# %%
df = df.drop(columns=['match_id'])
print(df.head())
# Out:
#         batsmanName  runs  balls minutes  4s  6s      SR  \
# 0    Marcus Stoinis     0      1       -   0   0    0.00
# 1    Shikhar Dhawan    15     13       -   3   0  115.38
# 2    Ajinkya Rahane     2      4       -   0   0   50.00
# 3  Shreyas Iyer (c)    65     50       -   6   2  130.00
# 4    Rishabh Pant †    56     38       -   4   2  147.36
#
#                                          player_link
# 0  https://www.espncricinfo.com/cricketers/marcus...
# 1  https://www.espncricinfo.com/cricketers/shikha...
# 2  https://www.espncricinfo.com/cricketers/ajinky...
# 3  https://www.espncricinfo.com/cricketers/shreya...
# 4  https://www.espncricinfo.com/cricketers/rishab...

# %%
df = df.sort_values(by='batsmanName')

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0       -
#
#                                            player_link
# 832  https://www.espncricinfo.com/cricketers/ab-de-...
# 788  https://www.espncricinfo.com/cricketers/ab-de-...
# 607  https://www.espncricinfo.com/cricketers/ab-de-...
# 666  https://www.espncricinfo.com/cricketers/ab-de-...
# 496  https://www.espncricinfo.com/cricketers/ab-de-...
# ..                                                 ...
# 812  https://www.espncricinfo.com/cricketers/yashas...
# 587  https://www.espncricinfo.com/cricketers/yashas...
# 533  https://www.espncricinfo.com/cricketers/yashas...
# 794  https://www.espncricinfo.com/cricketers/yuzven...
# 614  https://www.espncricinfo.com/cricketers/yuzven...
#
# [883 rows x 8 columns]

# %%
df.describe()
# Out:
#              runs       balls          4s          6s
# count  883.000000  883.000000  883.000000  883.000000
# mean    20.960362   15.922990    1.791619    0.831257
# std     22.127020   14.174198    2.315691    1.396407
# min      0.000000    0.000000    0.000000    0.000000
# 25%      4.000000    5.000000    0.000000    0.000000
# 50%     13.000000   11.000000    1.000000    0.000000
# 75%     31.000000   24.000000    3.000000    1.000000
# max    132.000000   69.000000   14.000000    9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 883 entries, 832 to 614
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   batsmanName  883 non-null    object
#  1   runs         883 non-null    int64
#  2   balls        883 non-null    int64
#  3   minutes      883 non-null    object
#  4   4s           883 non-null    int64
#  5   6s           883 non-null    int64
#  6   SR           883 non-null    object
#  7   player_link  883 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 62.1+ KB

# %%
name_counts = df['batsmanName'].value_counts()

# Step 2: Add a new column to the DataFrame that shows how many times each player appears
df['inning_batted'] = df['batsmanName'].map(name_counts)

# Step 3: Display the updated DataFrame
print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0       -
#
#                                            player_link  inning_batted
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
# [883 rows x 9 columns]

# %%
print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0       -
#
#                                            player_link  inning_batted
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
# [883 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce')

df_cleaned = df[(df['SR'] != 0) & (df['SR'].notna())]

print(df_cleaned)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 832     AB de Villiers    51     30       -   4   2  170.00
# 788     AB de Villiers    28     18       -   4   1  155.55
# 607   AB de Villiers †     9      6       -   2   0  150.00
# 666   AB de Villiers †    12     10       -   1   0  120.00
# 232   AB de Villiers †    39     36       -   4   0  108.33
# ..                 ...   ...    ...     ...  ..  ..     ...
# 73   Wriddhiman Saha †    58     45       -   7   1  128.88
# 130  Wriddhiman Saha †    39     32       -   4   1  121.87
# 812   Yashasvi Jaiswal     6      6       -   1   0  100.00
# 533   Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794   Yuzvendra Chahal     1      3       -   0   0   33.33
#
#                                            player_link  inning_batted
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 232  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 73   https://www.espncricinfo.com/cricketers/wriddh...              4
# 130  https://www.espncricinfo.com/cricketers/wriddh...              4
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
#
# [792 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce').fillna(0)

df['Average_SR'] = df.groupby('batsmanName')['SR'].transform('mean')

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0    0.00
#
#                                            player_link  inning_batted  \
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR
# 832  162.775000
# 788  162.775000
# 607  136.715833
# 666  136.715833
# 496  136.715833
# ..          ...
# 812   64.813333
# 587   64.813333
# 533   64.813333
# 794   16.665000
# 614   16.665000
#
# [883 rows x 10 columns]

# %%
df['boundaries'] = df['4s'] + df['6s']

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0    0.00
#
#                                            player_link  inning_batted  \
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries
# 832  162.775000           6
# 788  162.775000           5
# 607  136.715833           2
# 666  136.715833           1
# 496  136.715833           0
# ..          ...         ...
# 812   64.813333           1
# 587   64.813333           0
# 533   64.813333           3
# 794   16.665000           0
# 614   16.665000           0
#
# [883 rows x 11 columns]

# %%
df['boundary_runs'] = (df['4s'] * 4) + (df['6s'] * 6)

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0    0.00
#
#                                            player_link  inning_batted  \
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs
# 832  162.775000           6             28
# 788  162.775000           5             22
# 607  136.715833           2              8
# 666  136.715833           1              4
# 496  136.715833           0              0
# ..          ...         ...            ...
# 812   64.813333           1              4
# 587   64.813333           0              0
# 533   64.813333           3             16
# 794   16.665000           0              0
# 614   16.665000           0              0
#
# [883 rows x 12 columns]

# %%
df['boundary_percentage'] = (df['boundary_runs'] / df['runs']) * 100

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0    0.00
#
#                                            player_link  inning_batted  \
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage
# 832  162.775000           6             28            54.901961
# 788  162.775000           5             22            78.571429
# 607  136.715833           2              8            88.888889
# 666  136.715833           1              4            33.333333
# 496  136.715833           0              0                  NaN
# ..          ...         ...            ...                  ...
# 812   64.813333           1              4            66.666667
# 587   64.813333           0              0                  NaN
# 533   64.813333           3             16            47.058824
# 794   16.665000           0              0             0.000000
# 614   16.665000           0              0                  NaN
#
# [883 rows x 13 columns]

# %%
df['Average_Boundary_Percentage'] = df.groupby('batsmanName')['boundary_percentage'].transform('mean')

df
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0    0.00
#
#                                            player_link  inning_batted  \
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 832  162.775000           6             28            54.901961
# 788  162.775000           5             22            78.571429
# 607  136.715833           2              8            88.888889
# 666  136.715833           1              4            33.333333
# 496  136.715833           0              0                  NaN
# ..          ...         ...            ...                  ...
# 812   64.813333           1              4            66.666667
# 587   64.813333           0              0                  NaN
# 533   64.813333           3             16            47.058824
# 794   16.665000           0              0             0.000000
# 614   16.665000           0              0                  NaN
#
#      Average_Boundary_Percentage
# 832                    66.736695
# 788                    66.736695
# 607                    52.288786
# 666                    52.288786
# 496                    52.288786
# ..                           ...
# 812                    56.862745
# 587                    56.862745
# 533                    56.862745
# 794                     0.000000
# 614                     0.000000
#
# [883 rows x 14 columns]

# %%
df['total_runs'] = df.groupby('batsmanName')['runs'].transform('sum')
df['inning_batted'] = df.groupby('batsmanName')['inning_batted'].transform('count')

# Step 2: Calculate batting average for each player and add it to the DataFrame
df['batting_average'] = df['total_runs'] / df['inning_batted']

# Step 3: Display the updated DataFrame with batting averages and other columns
print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 812  Yashasvi Jaiswal     6      6       -   1   0  100.00
# 587  Yashasvi Jaiswal     0      2       -   0   0    0.00
# 533  Yashasvi Jaiswal    34     36       -   1   2   94.44
# 794  Yuzvendra Chahal     1      3       -   0   0   33.33
# 614  Yuzvendra Chahal     0      0       -   0   0    0.00
#
#                                            player_link  inning_batted  \
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# ..                                                 ...            ...
# 812  https://www.espncricinfo.com/cricketers/yashas...              3
# 587  https://www.espncricinfo.com/cricketers/yashas...              3
# 533  https://www.espncricinfo.com/cricketers/yashas...              3
# 794  https://www.espncricinfo.com/cricketers/yuzven...              2
# 614  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 832  162.775000           6             28            54.901961
# 788  162.775000           5             22            78.571429
# 607  136.715833           2              8            88.888889
# 666  136.715833           1              4            33.333333
# 496  136.715833           0              0                  NaN
# ..          ...         ...            ...                  ...
# 812   64.813333           1              4            66.666667
# 587   64.813333           0              0                  NaN
# 533   64.813333           3             16            47.058824
# 794   16.665000           0              0             0.000000
# 614   16.665000           0              0                  NaN
#
#      Average_Boundary_Percentage  total_runs  batting_average
# 832                    66.736695          79        39.500000
# 788                    66.736695          79        39.500000
# 607                    52.288786         375        31.250000
# 666                    52.288786         375        31.250000
# 496                    52.288786         375        31.250000
# ..                           ...         ...              ...
# 812                    56.862745          40        13.333333
# 587                    56.862745          40        13.333333
# 533                    56.862745          40        13.333333
# 794                     0.000000           1         0.500000
# 614                     0.000000           1         0.500000
#
# [883 rows x 16 columns]

# %%
df.to_csv('processed_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
columns_to_keep = ['batsmanName', 'inning_batted', 'Average_SR', 'Average_Boundary_Percentage', 'total_runs', 'batting_average']

# Create the new DataFrame with the specified columns
df2 = df[columns_to_keep]

# Display the new DataFrame
df2.head()
# Out:
#           batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 832    AB de Villiers              2  162.775000                    66.736695
# 788    AB de Villiers              2  162.775000                    66.736695
# 607  AB de Villiers †             12  136.715833                    52.288786
# 666  AB de Villiers †             12  136.715833                    52.288786
# 496  AB de Villiers †             12  136.715833                    52.288786
#
#      total_runs  batting_average
# 832          79            39.50
# 788          79            39.50
# 607         375            31.25
# 666         375            31.25
# 496         375            31.25

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 832     AB de Villiers              2  162.775000
# 607   AB de Villiers †             12  136.715833
# 406        Aaron Finch             12  105.430000
# 546        Abdul Samad              8  142.603750
# 550    Abhishek Sharma              7  129.677143
# ..                 ...            ...         ...
# 30     Virat Kohli (c)             15  102.825333
# 80   Washington Sundar              9  119.461111
# 758  Wriddhiman Saha †              4  135.212500
# 812   Yashasvi Jaiswal              3   64.813333
# 794   Yuzvendra Chahal              2   16.665000
#
#      Average_Boundary_Percentage  total_runs  batting_average
# 832                    66.736695          79        39.500000
# 607                    52.288786         375        31.250000
# 406                    58.341588         268        22.333333
# 546                    55.993117         111        13.875000
# 550                    40.920562          71        10.142857
# ..                           ...         ...              ...
# 30                     21.307264         466        31.066667
# 80                     45.764921         111        12.333333
# 758                    54.332449         214        53.500000
# 812                    56.862745          40        13.333333
# 794                     0.000000           1         0.500000
#
# [144 rows x 6 columns]

# %%
df2.to_csv('final_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
# for openers
filtered_df2 = df2[
    (df2['batting_average'] > 30) &
    (df2['Average_SR'] >140) &
    (df2['inning_batted'] > 3) &
    (df2['Average_Boundary_Percentage'] > 50)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#        batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0  Eoin Morgan (c)              7  148.384286                    66.037492
# 1   Mayank Agarwal             11  143.500909                    52.575991
#
#    total_runs  batting_average
# 0         243        34.714286
# 1         424        38.545455

# %%
selected_players = filtered_df2['batsmanName']
selected_players
# Out:
# 0    Eoin Morgan (c)
# 1     Mayank Agarwal
# Name: batsmanName, dtype: object

# %% [markdown]
# # Filter criteria: (typically for middle order)
# # Batting Average > 40
# # Strike Rate > 125
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 20

# %%
df['total_balls'] = df.groupby('batsmanName')['balls'].transform('sum')

df['innings_played'] = df.groupby('batsmanName')['inning_batted'].transform('count')
df['balls_avg'] = df['total_balls'] / df['innings_played']
df.head(10)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 832    AB de Villiers    51     30       -   4   2  170.00
# 788    AB de Villiers    28     18       -   4   1  155.55
# 607  AB de Villiers †     9      6       -   2   0  150.00
# 666  AB de Villiers †    12     10       -   1   0  120.00
# 496  AB de Villiers †     0      2       -   0   0    0.00
# 232  AB de Villiers †    39     36       -   4   0  108.33
# 77   AB de Villiers †    35     21       -   1   2  166.66
# 123  AB de Villiers †    24     24       -   1   1  100.00
# 176  AB de Villiers †    15     12       -   1   1  125.00
# 411  AB de Villiers †     2      5       -   0   0   40.00
#
#                                            player_link  inning_batted  \
# 832  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 788  https://www.espncricinfo.com/cricketers/ab-de-...              2
# 607  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 666  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 496  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 232  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 77   https://www.espncricinfo.com/cricketers/ab-de-...             12
# 123  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 176  https://www.espncricinfo.com/cricketers/ab-de-...             12
# 411  https://www.espncricinfo.com/cricketers/ab-de-...             12
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 832  162.775000           6             28            54.901961
# 788  162.775000           5             22            78.571429
# 607  136.715833           2              8            88.888889
# 666  136.715833           1              4            33.333333
# 496  136.715833           0              0                  NaN
# 232  136.715833           4             16            41.025641
# 77   136.715833           3             16            45.714286
# 123  136.715833           2             10            41.666667
# 176  136.715833           2             10            66.666667
# 411  136.715833           0              0             0.000000
#
#      Average_Boundary_Percentage  total_runs  batting_average  total_balls  \
# 832                    66.736695          79            39.50           48
# 788                    66.736695          79            39.50           48
# 607                    52.288786         375            31.25          238
# 666                    52.288786         375            31.25          238
# 496                    52.288786         375            31.25          238
# 232                    52.288786         375            31.25          238
# 77                     52.288786         375            31.25          238
# 123                    52.288786         375            31.25          238
# 176                    52.288786         375            31.25          238
# 411                    52.288786         375            31.25          238
#
#      innings_played  balls_avg
# 832               2  24.000000
# 788               2  24.000000
# 607              12  19.833333
# 666              12  19.833333
# 496              12  19.833333
# 232              12  19.833333
# 77               12  19.833333
# 123              12  19.833333
# 176              12  19.833333
# 411              12  19.833333

# %%
# Merge df2 with df to add the balls_avg column
df2 = df2.merge(df[['batsmanName', 'balls_avg']], on='batsmanName', how='left')

# Display the updated df2
print(df2)
# Out:
#           batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0      AB de Villiers              2  162.775000                    66.736695
# 1      AB de Villiers              2  162.775000                    66.736695
# 2    AB de Villiers †             12  136.715833                    52.288786
# 3    AB de Villiers †             12  136.715833                    52.288786
# 4    AB de Villiers †             12  136.715833                    52.288786
# ..                ...            ...         ...                          ...
# 878  Yashasvi Jaiswal              3   64.813333                    56.862745
# 879  Yashasvi Jaiswal              3   64.813333                    56.862745
# 880  Yashasvi Jaiswal              3   64.813333                    56.862745
# 881  Yuzvendra Chahal              2   16.665000                     0.000000
# 882  Yuzvendra Chahal              2   16.665000                     0.000000
#
#      total_runs  batting_average  balls_avg
# 0            79        39.500000  24.000000
# 1            79        39.500000  24.000000
# 2           375        31.250000  19.833333
# 3           375        31.250000  19.833333
# 4           375        31.250000  19.833333
# ..          ...              ...        ...
# 878          40        13.333333  14.666667
# 879          40        13.333333  14.666667
# 880          40        13.333333  14.666667
# 881           1         0.500000   1.500000
# 882           1         0.500000   1.500000
#
# [883 rows x 7 columns]

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 0       AB de Villiers              2  162.775000
# 2     AB de Villiers †             12  136.715833
# 14         Aaron Finch             12  105.430000
# 26         Abdul Samad              8  142.603750
# 34     Abhishek Sharma              7  129.677143
# ..                 ...            ...         ...
# 850    Virat Kohli (c)             15  102.825333
# 865  Washington Sundar              9  119.461111
# 874  Wriddhiman Saha †              4  135.212500
# 878   Yashasvi Jaiswal              3   64.813333
# 881   Yuzvendra Chahal              2   16.665000
#
#      Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                      66.736695          79        39.500000  24.000000
# 2                      52.288786         375        31.250000  19.833333
# 14                     58.341588         268        22.333333  20.083333
# 26                     55.993117         111        13.875000   8.125000
# 34                     40.920562          71        10.142857   8.000000
# ..                           ...         ...              ...        ...
# 850                    21.307264         466        31.066667  25.600000
# 865                    45.764921         111        12.333333  10.555556
# 874                    54.332449         214        53.500000  38.250000
# 878                    56.862745          40        13.333333  14.666667
# 881                     0.000000           1         0.500000   1.500000
#
# [144 rows x 7 columns]

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 35) &
    (df2['Average_SR'] > 125) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 20)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#          batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0         Ben Stokes              8  135.017500                    64.078892
# 1        Chris Gayle              7  135.895714                    61.544758
# 2       Ishan Kishan             13  132.149231                    60.307419
# 3     Mayank Agarwal             11  143.500909                    52.575991
# 4  Wriddhiman Saha †              4  135.212500                    54.332449
#
#    total_runs  batting_average  balls_avg
# 0         285        35.625000  25.000000
# 1         288        41.142857  30.000000
# 2         516        39.692308  27.230769
# 3         424        38.545455  24.636364
# 4         214        53.500000  38.250000

# %%
combined_df = pd.concat([filtered_df2, selected_players])
combined_df.to_csv('selected_players.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %% [markdown]
# # Filter criteria: (typically for lower order)
# # Batting Average > 25
# # Strike Rate > 130
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 12
# # Innings Bowled > 1

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 25) &
    (df2['Average_SR'] > 130) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 12)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2.to_csv('temp.csv', index=False)
filtered_df2
# Out:
#          batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0   AB de Villiers †             12  136.715833                    52.288786
# 1         Ben Stokes              8  135.017500                    64.078892
# 2        Chris Gayle              7  135.895714                    61.544758
# 3    Eoin Morgan (c)              7  148.384286                    66.037492
# 4       Ishan Kishan             13  132.149231                    60.307419
# 5        Jos Buttler              5  135.184000                    46.878788
# 6     Kieron Pollard             10  174.248000                    65.619420
# 7     Mayank Agarwal             11  143.500909                    52.575991
# 8     Sanju Samson †              7  130.128571                    54.806890
# 9  Wriddhiman Saha †              4  135.212500                    54.332449
#
#    total_runs  batting_average  balls_avg
# 0         375        31.250000  19.833333
# 1         285        35.625000  25.000000
# 2         288        41.142857  30.000000
# 3         243        34.714286  23.857143
# 4         516        39.692308  27.230769
# 5         160        32.000000  23.600000
# 6         258        25.800000  13.500000
# 7         424        38.545455  24.636364
# 8         222        31.714286  18.142857
# 9         214        53.500000  38.250000
