# %%
import pandas as pd

# %% [markdown]
# # Filter criteria: (typically for openers)
# # 1. Batting Average > 30
# # 2. Strike Rate > 140
# # 3. Innings Batted >= 3
# # 4. Boundary % > 50

# %%
file_path = "icc_t20_worldcup_batting.csv"  
df = pd.read_csv(file_path)
print(df.head())
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR   match_id
# 0       Martin Guptill    28     35      53   3   0   80.00  scorecard
# 1       Daryl Mitchell    11      8      18   0   1  137.50  scorecard
# 2  Kane Williamson (c)    85     48      69  10   3  177.08  scorecard
# 3       Glenn Phillips    18     17      32   1   1  105.88  scorecard
# 4        James Neesham    13      7      17   0   1  185.71  scorecard

# %%
df = df.drop(columns=['match_id'])
print(df.head())
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR
# 0       Martin Guptill    28     35      53   3   0   80.00
# 1       Daryl Mitchell    11      8      18   0   1  137.50
# 2  Kane Williamson (c)    85     48      69  10   3  177.08
# 3       Glenn Phillips    18     17      32   1   1  105.88
# 4        James Neesham    13      7      17   0   1  185.71

# %%
df = df.sort_values(by='batsmanName')

print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR
# 17       Aaron Finch (c)     0      1       2   0   0    0.00
# 101      Aaron Finch (c)     9     11      18   1   0   81.81
# 268      Aaron Finch (c)    44     49      89   4   0   89.79
# 341      Aaron Finch (c)    37     23      33   5   2  160.86
# 7        Aaron Finch (c)     5      7      12   1   0   71.42
# ..                   ...   ...    ...     ...  ..  ..     ...
# 507         Zane Green †    24     32      64   1   0   75.00
# 260         Zane Green †     1      7      12   0   0   14.28
# 356         Zane Green †     9     13      20   1   0   69.23
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33
#
# [685 rows x 7 columns]

# %%
name_counts = df['batsmanName'].value_counts()

# Step 2: Add a new column to the DataFrame that shows how many times each player appears
df['inning_batted'] = df['batsmanName'].map(name_counts)

# Step 3: Display the updated DataFrame
print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
# [685 rows x 8 columns]

# %%
print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
# [685 rows x 8 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce')

df_cleaned = df[(df['SR'] != 0) & (df['SR'].notna())]

print(df_cleaned)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# 161      Aaron Finch (c)    40     20      27   2   4  200.00              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
# [591 rows x 8 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce').fillna(0)

df['Average_SR'] = df.groupby('batsmanName')['SR'].transform('mean')

print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted  \
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
#      Average_SR
# 17    86.268571
# 101   86.268571
# 268   86.268571
# 341   86.268571
# 7     86.268571
# ..          ...
# 507   61.460000
# 260   61.460000
# 356   61.460000
# 591   94.165000
# 514   94.165000
#
# [685 rows x 9 columns]

# %%
df['boundaries'] = df['4s'] + df['6s']

print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted  \
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
#      Average_SR  boundaries
# 17    86.268571           0
# 101   86.268571           1
# 268   86.268571           4
# 341   86.268571           7
# 7     86.268571           1
# ..          ...         ...
# 507   61.460000           1
# 260   61.460000           0
# 356   61.460000           1
# 591   94.165000           1
# 514   94.165000           4
#
# [685 rows x 10 columns]

# %%
df['boundary_runs'] = (df['4s'] * 4) + (df['6s'] * 6)

print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted  \
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
#      Average_SR  boundaries  boundary_runs
# 17    86.268571           0              0
# 101   86.268571           1              4
# 268   86.268571           4             16
# 341   86.268571           7             32
# 7     86.268571           1              4
# ..          ...         ...            ...
# 507   61.460000           1              4
# 260   61.460000           0              0
# 356   61.460000           1              4
# 591   94.165000           1              6
# 514   94.165000           4             18
#
# [685 rows x 11 columns]

# %%
df['boundary_percentage'] = (df['boundary_runs'] / df['runs']) * 100

print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted  \
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage
# 17    86.268571           0              0                  NaN
# 101   86.268571           1              4            44.444444
# 268   86.268571           4             16            36.363636
# 341   86.268571           7             32            86.486486
# 7     86.268571           1              4            80.000000
# ..          ...         ...            ...                  ...
# 507   61.460000           1              4            16.666667
# 260   61.460000           0              0             0.000000
# 356   61.460000           1              4            44.444444
# 591   94.165000           1              6            50.000000
# 514   94.165000           4             18            52.941176
#
# [685 rows x 12 columns]

# %%
df['Average_Boundary_Percentage'] = df.groupby('batsmanName')['boundary_percentage'].transform('mean')

df
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted  \
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 17    86.268571           0              0                  NaN
# 101   86.268571           1              4            44.444444
# 268   86.268571           4             16            36.363636
# 341   86.268571           7             32            86.486486
# 7     86.268571           1              4            80.000000
# ..          ...         ...            ...                  ...
# 507   61.460000           1              4            16.666667
# 260   61.460000           0              0             0.000000
# 356   61.460000           1              4            44.444444
# 591   94.165000           1              6            50.000000
# 514   94.165000           4             18            52.941176
#
#      Average_Boundary_Percentage
# 17                     65.458913
# 101                    65.458913
# 268                    65.458913
# 341                    65.458913
# 7                      65.458913
# ..                           ...
# 507                    30.764895
# 260                    30.764895
# 356                    30.764895
# 591                    51.470588
# 514                    51.470588
#
# [685 rows x 13 columns]

# %%
df['total_runs'] = df.groupby('batsmanName')['runs'].transform('sum')
df['inning_batted'] = df.groupby('batsmanName')['inning_batted'].transform('count')

# Step 2: Calculate batting average for each player and add it to the DataFrame
df['batting_average'] = df['total_runs'] / df['inning_batted']

# Step 3: Display the updated DataFrame with batting averages and other columns
print(df)
# Out:
#              batsmanName  runs  balls minutes  4s  6s      SR  inning_batted  \
# 17       Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101      Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268      Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341      Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7        Aaron Finch (c)     5      7      12   1   0   71.42              7
# ..                   ...   ...    ...     ...  ..  ..     ...            ...
# 507         Zane Green †    24     32      64   1   0   75.00              7
# 260         Zane Green †     1      7      12   0   0   14.28              7
# 356         Zane Green †     9     13      20   1   0   69.23              7
# 591  Zeeshan Maqsood (c)    12     16      28   0   1   75.00              2
# 514  Zeeshan Maqsood (c)    34     30      49   3   1  113.33              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 17    86.268571           0              0                  NaN
# 101   86.268571           1              4            44.444444
# 268   86.268571           4             16            36.363636
# 341   86.268571           7             32            86.486486
# 7     86.268571           1              4            80.000000
# ..          ...         ...            ...                  ...
# 507   61.460000           1              4            16.666667
# 260   61.460000           0              0             0.000000
# 356   61.460000           1              4            44.444444
# 591   94.165000           1              6            50.000000
# 514   94.165000           4             18            52.941176
#
#      Average_Boundary_Percentage  total_runs  batting_average
# 17                     65.458913         135        19.285714
# 101                    65.458913         135        19.285714
# 268                    65.458913         135        19.285714
# 341                    65.458913         135        19.285714
# 7                      65.458913         135        19.285714
# ..                           ...         ...              ...
# 507                    30.764895          80        11.428571
# 260                    30.764895          80        11.428571
# 356                    30.764895          80        11.428571
# 591                    51.470588          46        23.000000
# 514                    51.470588          46        23.000000
#
# [685 rows x 15 columns]

# %%
df.to_csv('processed_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
columns_to_keep = ['batsmanName', 'inning_batted', 'Average_SR', 'Average_Boundary_Percentage', 'total_runs', 'batting_average']

# Create the new DataFrame with the specified columns
df2 = df[columns_to_keep]

# Display the new DataFrame
df2.head()
# Out:
#          batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 17   Aaron Finch (c)              7   86.268571                    65.458913
# 101  Aaron Finch (c)              7   86.268571                    65.458913
# 268  Aaron Finch (c)              7   86.268571                    65.458913
# 341  Aaron Finch (c)              7   86.268571                    65.458913
# 7    Aaron Finch (c)              7   86.268571                    65.458913
#
#      total_runs  batting_average
# 17          135        19.285714
# 101         135        19.285714
# 268         135        19.285714
# 341         135        19.285714
# 7           135        19.285714

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#              batsmanName  inning_batted  Average_SR  \
# 17       Aaron Finch (c)              7   86.268571
# 276           Adam Zampa              1   25.000000
# 89           Adil Rashid              1  100.000000
# 331         Afif Hossain              8   77.498750
# 466        Aiden Markram              5  122.052000
# ..                   ...            ...         ...
# 609             Tony Ura              2   33.330000
# 424      Virat Kohli (c)              3   89.753333
# 549    Wanindu Hasaranga              5  142.592000
# 43          Zane Green †              7   61.460000
# 591  Zeeshan Maqsood (c)              2   94.165000
#
#      Average_Boundary_Percentage  total_runs  batting_average
# 17                     65.458913         135        19.285714
# 276                     0.000000           1         1.000000
# 89                      0.000000           2         2.000000
# 331                    39.788360          54         6.750000
# 466                    52.847206         162        32.400000
# ..                           ...         ...              ...
# 609                     0.000000           2         1.000000
# 424                    15.204678          68        22.666667
# 549                    56.879315         119        23.800000
# 43                     30.764895          80        11.428571
# 591                    51.470588          46        23.000000
#
# [195 rows x 6 columns]

# %%
df2.to_csv('final_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
# for openers
filtered_df2 = df2[
    (df2['batting_average'] > 30) &
    (df2['Average_SR'] >140) &
    (df2['inning_batted'] > 3) &
    (df2['Average_Boundary_Percentage'] > 50)
]

filtered_df2
# Out:
#         batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 279   Jos Buttler †              6  145.976667                    59.964536
# 46         KL Rahul              5  141.380000                    50.938486
# 102  Mitchell Marsh              5  166.318000                    62.172874
#
#      total_runs  batting_average
# 279         269        44.833333
# 46          194        38.800000
# 102         185        37.000000

# %% [markdown]
# # Filter criteria: (typically for middle order)
# # Batting Average > 40
# # Strike Rate > 125
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 20

# %%
df['total_balls'] = df.groupby('batsmanName')['balls'].transform('sum')

df['innings_played'] = df.groupby('batsmanName')['inning_batted'].transform('count')
df['balls_avg'] = df['total_balls'] / df['innings_played']
df.head(10)
# Out:
#          batsmanName  runs  balls minutes  4s  6s      SR  inning_batted  \
# 17   Aaron Finch (c)     0      1       2   0   0    0.00              7
# 101  Aaron Finch (c)     9     11      18   1   0   81.81              7
# 268  Aaron Finch (c)    44     49      89   4   0   89.79              7
# 341  Aaron Finch (c)    37     23      33   5   2  160.86              7
# 7    Aaron Finch (c)     5      7      12   1   0   71.42              7
# 161  Aaron Finch (c)    40     20      27   2   4  200.00              7
# 475  Aaron Finch (c)     0      5      22   0   0    0.00              7
# 276       Adam Zampa     1      4       8   0   0   25.00              1
# 89       Adil Rashid     2      2       4   0   0  100.00              1
# 331     Afif Hossain     2      2       7   0   0  100.00              8
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 17    86.268571           0              0                  NaN
# 101   86.268571           1              4            44.444444
# 268   86.268571           4             16            36.363636
# 341   86.268571           7             32            86.486486
# 7     86.268571           1              4            80.000000
# 161   86.268571           6             32            80.000000
# 475   86.268571           0              0                  NaN
# 276   25.000000           0              0             0.000000
# 89   100.000000           0              0             0.000000
# 331   77.498750           0              0             0.000000
#
#      Average_Boundary_Percentage  total_runs  batting_average  total_balls  \
# 17                     65.458913         135        19.285714          116
# 101                    65.458913         135        19.285714          116
# 268                    65.458913         135        19.285714          116
# 341                    65.458913         135        19.285714          116
# 7                      65.458913         135        19.285714          116
# 161                    65.458913         135        19.285714          116
# 475                    65.458913         135        19.285714          116
# 276                     0.000000           1         1.000000            4
# 89                      0.000000           2         2.000000            2
# 331                    39.788360          54         6.750000           50
#
#      innings_played  balls_avg
# 17                7  16.571429
# 101               7  16.571429
# 268               7  16.571429
# 341               7  16.571429
# 7                 7  16.571429
# 161               7  16.571429
# 475               7  16.571429
# 276               1   4.000000
# 89                1   2.000000
# 331               8   6.250000

# %%
# Merge df2 with df to add the balls_avg column
df2 = df2.merge(df[['batsmanName', 'balls_avg']], on='batsmanName', how='left')

# Display the updated df2
print(df2)
# Out:
#              batsmanName  inning_batted  Average_SR  \
# 0        Aaron Finch (c)              7   86.268571
# 1        Aaron Finch (c)              7   86.268571
# 2        Aaron Finch (c)              7   86.268571
# 3        Aaron Finch (c)              7   86.268571
# 4        Aaron Finch (c)              7   86.268571
# ..                   ...            ...         ...
# 680         Zane Green †              7   61.460000
# 681         Zane Green †              7   61.460000
# 682         Zane Green †              7   61.460000
# 683  Zeeshan Maqsood (c)              2   94.165000
# 684  Zeeshan Maqsood (c)              2   94.165000
#
#      Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                      65.458913         135        19.285714  16.571429
# 1                      65.458913         135        19.285714  16.571429
# 2                      65.458913         135        19.285714  16.571429
# 3                      65.458913         135        19.285714  16.571429
# 4                      65.458913         135        19.285714  16.571429
# ..                           ...         ...              ...        ...
# 680                    30.764895          80        11.428571  15.000000
# 681                    30.764895          80        11.428571  15.000000
# 682                    30.764895          80        11.428571  15.000000
# 683                    51.470588          46        23.000000  23.000000
# 684                    51.470588          46        23.000000  23.000000
#
# [685 rows x 7 columns]

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#              batsmanName  inning_batted  Average_SR  \
# 0        Aaron Finch (c)              7   86.268571
# 7             Adam Zampa              1   25.000000
# 8            Adil Rashid              1  100.000000
# 9           Afif Hossain              8   77.498750
# 17         Aiden Markram              5  122.052000
# ..                   ...            ...         ...
# 666             Tony Ura              2   33.330000
# 668      Virat Kohli (c)              3   89.753333
# 671    Wanindu Hasaranga              5  142.592000
# 676         Zane Green †              7   61.460000
# 683  Zeeshan Maqsood (c)              2   94.165000
#
#      Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                      65.458913         135        19.285714  16.571429
# 7                       0.000000           1         1.000000   4.000000
# 8                       0.000000           2         2.000000   2.000000
# 9                      39.788360          54         6.750000   6.250000
# 17                     52.847206         162        32.400000  22.200000
# ..                           ...         ...              ...        ...
# 666                     0.000000           2         1.000000   4.000000
# 668                    15.204678          68        22.666667  22.666667
# 671                    56.879315         119        23.800000  16.000000
# 676                    30.764895          80        11.428571  15.000000
# 683                    51.470588          46        23.000000  23.000000
#
# [195 rows x 7 columns]

# %%
filtered_df3 = df2[
    (df2['batting_average'] > 35) &
    (df2['Average_SR'] > 125) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 20)
]

filtered_df3
# Out:
#           batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 96   Charith Asalanka              6  133.330000                    66.714519
# 154      David Warner              7  126.911429                    58.101511
# 300     Jos Buttler †              6  145.976667                    59.964536
# 312          KL Rahul              5  141.380000                    50.938486
# 445    Mitchell Marsh              5  166.318000                    62.172874
#
#      total_runs  batting_average  balls_avg
# 96          231        38.500000  26.166667
# 154         289        41.285714  28.142857
# 300         269        44.833333  29.666667
# 312         194        38.800000  25.400000
# 445         185        37.000000  25.200000

# %%
selected_players = pd.concat([filtered_df2['batsmanName'], filtered_df3['batsmanName']])
selected_players.to_csv('selected_players.csv', index=False)
selected_players
# Out:
# 279       Jos Buttler †
# 46             KL Rahul
# 102      Mitchell Marsh
# 96     Charith Asalanka
# 154        David Warner
# 300       Jos Buttler †
# 312            KL Rahul
# 445      Mitchell Marsh
# Name: batsmanName, dtype: object

# %% [markdown]
# # Filter criteria: (typically for lower order)
# # Batting Average > 25
# # Strike Rate > 130
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 12
# # Innings Bowled > 1

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 25) &
    (df2['Average_SR'] > 130) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 12)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2.to_csv('temp.csv', index=False)
filtered_df2
# Out:
#          batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0   Charith Asalanka              6  133.330000                    66.714519
# 1     Daryl Mitchell              7  136.027143                    54.601536
# 2      Jos Buttler †              6  145.976667                    59.964536
# 3           KL Rahul              5  141.380000                    50.938486
# 4     Mitchell Marsh              5  166.318000                    62.172874
# 5  Mohammad Nabi (c)              5  150.394000                    50.224026
#
#    total_runs  batting_average  balls_avg
# 0         231        38.500000  26.166667
# 1         208        29.714286  21.142857
# 2         269        44.833333  29.666667
# 3         194        38.800000  25.400000
# 4         185        37.000000  25.200000
# 5         127        25.400000  21.000000
