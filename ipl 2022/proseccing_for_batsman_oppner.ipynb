# %%
import pandas as pd

# %% [markdown]
# # Filter criteria: (typically for openers)
# # 1. Batting Average > 30
# # 2. Strike Rate > 140
# # 3. Innings Batted >= 3
# # 4. Boundary % > 50

# %%
file_path = "batting.csv"  
df = pd.read_csv(file_path)
print(df.head())
# Out:
#          batsmanName  runs  balls minutes  4s  6s      SR  \
# 0   Yashasvi Jaiswal    22     16      22   1   2  137.50
# 1        Jos Buttler    39     35      64   5   0  111.42
# 2  Sanju Samson (c)†    14     11      21   2   0  127.27
# 3   Devdutt Padikkal     2     10      20   0   0   20.00
# 4    Shimron Hetmyer    11     12      20   2   0   91.66
#
#                                          player_link   match_id
# 0  https://www.espncricinfo.com/cricketers/yashas...  scorecard
# 1  https://www.espncricinfo.com/cricketers/jos-bu...  scorecard
# 2  https://www.espncricinfo.com/cricketers/sanju-...  scorecard
# 3  https://www.espncricinfo.com/cricketers/devdut...  scorecard
# 4  https://www.espncricinfo.com/cricketers/shimro...  scorecard

# %%
df = df.drop(columns=['match_id'])
print(df.head())
# Out:
#          batsmanName  runs  balls minutes  4s  6s      SR  \
# 0   Yashasvi Jaiswal    22     16      22   1   2  137.50
# 1        Jos Buttler    39     35      64   5   0  111.42
# 2  Sanju Samson (c)†    14     11      21   2   0  127.27
# 3   Devdutt Padikkal     2     10      20   0   0   20.00
# 4    Shimron Hetmyer    11     12      20   2   0   91.66
#
#                                          player_link
# 0  https://www.espncricinfo.com/cricketers/yashas...
# 1  https://www.espncricinfo.com/cricketers/jos-bu...
# 2  https://www.espncricinfo.com/cricketers/sanju-...
# 3  https://www.espncricinfo.com/cricketers/devdut...
# 4  https://www.espncricinfo.com/cricketers/shimro...

# %%
df = df.sort_values(by='batsmanName')

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0       -
#
#                                            player_link
# 440  https://www.espncricinfo.com/cricketers/aaron-...
# 708  https://www.espncricinfo.com/cricketers/aaron-...
# 518  https://www.espncricinfo.com/cricketers/aaron-...
# 345  https://www.espncricinfo.com/cricketers/aaron-...
# 784  https://www.espncricinfo.com/cricketers/aaron-...
# ..                                                 ...
# 362  https://www.espncricinfo.com/cricketers/yashas...
# 44   https://www.espncricinfo.com/cricketers/yashas...
# 0    https://www.espncricinfo.com/cricketers/yashas...
# 813  https://www.espncricinfo.com/cricketers/yuzven...
# 561  https://www.espncricinfo.com/cricketers/yuzven...
#
# [1176 rows x 8 columns]

# %%
df.describe()
# Out:
#               runs        balls           4s           6s
# count  1176.000000  1176.000000  1176.000000  1176.000000
# mean     19.602041    14.634354     1.715136     0.903061
# std      21.504868    13.403803     2.246808     1.419904
# min       0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     4.000000     0.000000     0.000000
# 50%      12.000000    11.000000     1.000000     0.000000
# 75%      30.000000    21.000000     3.000000     1.000000
# max     140.000000    70.000000    13.000000    10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1176 entries, 440 to 561
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   batsmanName  1176 non-null   object
#  1   runs         1176 non-null   int64
#  2   balls        1176 non-null   int64
#  3   minutes      1176 non-null   object
#  4   4s           1176 non-null   int64
#  5   6s           1176 non-null   int64
#  6   SR           1176 non-null   object
#  7   player_link  1176 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 82.7+ KB

# %%
name_counts = df['batsmanName'].value_counts()

# Step 2: Add a new column to the DataFrame that shows how many times each player appears
df['inning_batted'] = df['batsmanName'].map(name_counts)

# Step 3: Display the updated DataFrame
print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0       -
#
#                                            player_link  inning_batted
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
# [1176 rows x 9 columns]

# %%
print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0       -
#
#                                            player_link  inning_batted
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
# [1176 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce')

df_cleaned = df[(df['SR'] != 0) & (df['SR'].notna())]

print(df_cleaned)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 440        Aaron Finch     4      7      16   0   0   57.14
# 708        Aaron Finch    58     28      49   9   2  207.14
# 518        Aaron Finch     3      7       9   0   0   42.85
# 345        Aaron Finch    14     14      29   1   0  100.00
# 784        Aaron Finch     7      5      10   0   1  140.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1107  Yashasvi Jaiswal    20     16      33   2   1  125.00
# 362   Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44    Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0     Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813   Yuzvendra Chahal     5      8      11   0   0   62.50
#
#                                             player_link  inning_batted
# 440   https://www.espncricinfo.com/cricketers/aaron-...              5
# 708   https://www.espncricinfo.com/cricketers/aaron-...              5
# 518   https://www.espncricinfo.com/cricketers/aaron-...              5
# 345   https://www.espncricinfo.com/cricketers/aaron-...              5
# 784   https://www.espncricinfo.com/cricketers/aaron-...              5
# ...                                                 ...            ...
# 1107  https://www.espncricinfo.com/cricketers/yashas...             10
# 362   https://www.espncricinfo.com/cricketers/yashas...             10
# 44    https://www.espncricinfo.com/cricketers/yashas...             10
# 0     https://www.espncricinfo.com/cricketers/yashas...             10
# 813   https://www.espncricinfo.com/cricketers/yuzven...              2
#
# [1036 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce').fillna(0)

df['Average_SR'] = df.groupby('batsmanName')['SR'].transform('mean')

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0    0.00
#
#                                            player_link  inning_batted  \
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR
# 440     109.426
# 708     109.426
# 518     109.426
# 345     109.426
# 784     109.426
# ..          ...
# 362     111.950
# 44      111.950
# 0       111.950
# 813      31.250
# 561      31.250
#
# [1176 rows x 10 columns]

# %%
df['boundaries'] = df['4s'] + df['6s']

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0    0.00
#
#                                            player_link  inning_batted  \
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries
# 440     109.426           0
# 708     109.426          11
# 518     109.426           0
# 345     109.426           1
# 784     109.426           1
# ..          ...         ...
# 362     111.950          11
# 44      111.950           0
# 0       111.950           3
# 813      31.250           0
# 561      31.250           0
#
# [1176 rows x 11 columns]

# %%
df['boundary_runs'] = (df['4s'] * 4) + (df['6s'] * 6)

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0    0.00
#
#                                            player_link  inning_batted  \
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs
# 440     109.426           0              0
# 708     109.426          11             48
# 518     109.426           0              0
# 345     109.426           1              4
# 784     109.426           1              6
# ..          ...         ...            ...
# 362     111.950          11             48
# 44      111.950           0              0
# 0       111.950           3             16
# 813      31.250           0              0
# 561      31.250           0              0
#
# [1176 rows x 12 columns]

# %%
df['boundary_percentage'] = (df['boundary_runs'] / df['runs']) * 100

print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0    0.00
#
#                                            player_link  inning_batted  \
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage
# 440     109.426           0              0             0.000000
# 708     109.426          11             48            82.758621
# 518     109.426           0              0             0.000000
# 345     109.426           1              4            28.571429
# 784     109.426           1              6            85.714286
# ..          ...         ...            ...                  ...
# 362     111.950          11             48            70.588235
# 44      111.950           0              0             0.000000
# 0       111.950           3             16            72.727273
# 813      31.250           0              0             0.000000
# 561      31.250           0              0                  NaN
#
# [1176 rows x 13 columns]

# %%
df['Average_Boundary_Percentage'] = df.groupby('batsmanName')['boundary_percentage'].transform('mean')

df
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0    0.00
#
#                                            player_link  inning_batted  \
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 440     109.426           0              0             0.000000
# 708     109.426          11             48            82.758621
# 518     109.426           0              0             0.000000
# 345     109.426           1              4            28.571429
# 784     109.426           1              6            85.714286
# ..          ...         ...            ...                  ...
# 362     111.950          11             48            70.588235
# 44      111.950           0              0             0.000000
# 0       111.950           3             16            72.727273
# 813      31.250           0              0             0.000000
# 561      31.250           0              0                  NaN
#
#      Average_Boundary_Percentage
# 440                    39.408867
# 708                    39.408867
# 518                    39.408867
# 345                    39.408867
# 784                    39.408867
# ..                           ...
# 362                    47.971507
# 44                     47.971507
# 0                      47.971507
# 813                     0.000000
# 561                     0.000000
#
# [1176 rows x 14 columns]

# %%
df['total_runs'] = df.groupby('batsmanName')['runs'].transform('sum')
df['inning_batted'] = df.groupby('batsmanName')['inning_batted'].transform('count')

# Step 2: Calculate batting average for each player and add it to the DataFrame
df['batting_average'] = df['total_runs'] / df['inning_batted']

# Step 3: Display the updated DataFrame with batting averages and other columns
print(df)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# ..                ...   ...    ...     ...  ..  ..     ...
# 362  Yashasvi Jaiswal    68     41      73   9   2  165.85
# 44   Yashasvi Jaiswal     3      8      11   0   0   37.50
# 0    Yashasvi Jaiswal    22     16      22   1   2  137.50
# 813  Yuzvendra Chahal     5      8      11   0   0   62.50
# 561  Yuzvendra Chahal     0      0       7   0   0    0.00
#
#                                            player_link  inning_batted  \
# 440  https://www.espncricinfo.com/cricketers/aaron-...              5
# 708  https://www.espncricinfo.com/cricketers/aaron-...              5
# 518  https://www.espncricinfo.com/cricketers/aaron-...              5
# 345  https://www.espncricinfo.com/cricketers/aaron-...              5
# 784  https://www.espncricinfo.com/cricketers/aaron-...              5
# ..                                                 ...            ...
# 362  https://www.espncricinfo.com/cricketers/yashas...             10
# 44   https://www.espncricinfo.com/cricketers/yashas...             10
# 0    https://www.espncricinfo.com/cricketers/yashas...             10
# 813  https://www.espncricinfo.com/cricketers/yuzven...              2
# 561  https://www.espncricinfo.com/cricketers/yuzven...              2
#
#      Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 440     109.426           0              0             0.000000
# 708     109.426          11             48            82.758621
# 518     109.426           0              0             0.000000
# 345     109.426           1              4            28.571429
# 784     109.426           1              6            85.714286
# ..          ...         ...            ...                  ...
# 362     111.950          11             48            70.588235
# 44      111.950           0              0             0.000000
# 0       111.950           3             16            72.727273
# 813      31.250           0              0             0.000000
# 561      31.250           0              0                  NaN
#
#      Average_Boundary_Percentage  total_runs  batting_average
# 440                    39.408867          86             17.2
# 708                    39.408867          86             17.2
# 518                    39.408867          86             17.2
# 345                    39.408867          86             17.2
# 784                    39.408867          86             17.2
# ..                           ...         ...              ...
# 362                    47.971507         258             25.8
# 44                     47.971507         258             25.8
# 0                      47.971507         258             25.8
# 813                     0.000000           5              2.5
# 561                     0.000000           5              2.5
#
# [1176 rows x 16 columns]

# %%
df.to_csv('processed_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
columns_to_keep = ['batsmanName', 'inning_batted', 'Average_SR', 'Average_Boundary_Percentage', 'total_runs', 'batting_average']

# Create the new DataFrame with the specified columns
df2 = df[columns_to_keep]

# Display the new DataFrame
df2.head()
# Out:
#      batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 440  Aaron Finch              5     109.426                    39.408867
# 708  Aaron Finch              5     109.426                    39.408867
# 518  Aaron Finch              5     109.426                    39.408867
# 345  Aaron Finch              5     109.426                    39.408867
# 784  Aaron Finch              5     109.426                    39.408867
#
#      total_runs  batting_average
# 440          86             17.2
# 708          86             17.2
# 518          86             17.2
# 345          86             17.2
# 784          86             17.2

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#             batsmanName  inning_batted  Average_SR  \
# 440         Aaron Finch              5  109.426000
# 1118        Abdul Samad              2   33.330000
# 119      Abhijeet Tomar              1   50.000000
# 1023    Abhinav Manohar              7  104.930000
# 615     Abhishek Sharma             14  112.892857
# ...                 ...            ...         ...
# 1120  Washington Sundar              7  127.694286
# 418   Wriddhiman Saha †             11  100.744545
# 627          Yash Dayal              1    0.000000
# 25     Yashasvi Jaiswal             10  111.950000
# 813    Yuzvendra Chahal              2   31.250000
#
#       Average_Boundary_Percentage  total_runs  batting_average
# 440                     39.408867          86        17.200000
# 1118                     0.000000           4         2.000000
# 119                    100.000000           4         4.000000
# 1023                    47.678110         108        15.428571
# 615                     55.777865         426        30.428571
# ...                           ...         ...              ...
# 1120                    24.888889         101        14.428571
# 418                     62.355482         317        28.818182
# 627                           NaN           0         0.000000
# 25                      47.971507         258        25.800000
# 813                      0.000000           5         2.500000
#
# [184 rows x 6 columns]

# %%
df2.to_csv('final_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
# for openers
filtered_df2 = df2[
    (df2['batting_average'] > 30) &
    (df2['Average_SR'] >140) &
    (df2['inning_batted'] > 3) &
    (df2['Average_Boundary_Percentage'] > 50)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#         batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0  Liam Livingstone             14  167.060714                    57.456103
# 1     Rajat Patidar              7  142.585714                    57.929591
#
#    total_runs  batting_average
# 0         437        31.214286
# 1         333        47.571429

# %%
selected_players = filtered_df2['batsmanName']
selected_players
# Out:
# 0    Liam Livingstone
# 1       Rajat Patidar
# Name: batsmanName, dtype: object

# %% [markdown]
# # Filter criteria: (typically for middle order)
# # Batting Average > 40
# # Strike Rate > 125
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 20

# %%
df['total_balls'] = df.groupby('batsmanName')['balls'].transform('sum')

df['innings_played'] = df.groupby('batsmanName')['inning_batted'].transform('count')
df['balls_avg'] = df['total_balls'] / df['innings_played']
df.head(10)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 440       Aaron Finch     4      7      16   0   0   57.14
# 708       Aaron Finch    58     28      49   9   2  207.14
# 518       Aaron Finch     3      7       9   0   0   42.85
# 345       Aaron Finch    14     14      29   1   0  100.00
# 784       Aaron Finch     7      5      10   0   1  140.00
# 1118      Abdul Samad     4      6       8   0   0   66.66
# 992       Abdul Samad     0      1       2   0   0    0.00
# 119    Abhijeet Tomar     4      8      15   1   0   50.00
# 1023  Abhinav Manohar     1      2       4   0   0   50.00
# 728   Abhinav Manohar    12     12      10   2   0  100.00
#
#                                             player_link  inning_batted  \
# 440   https://www.espncricinfo.com/cricketers/aaron-...              5
# 708   https://www.espncricinfo.com/cricketers/aaron-...              5
# 518   https://www.espncricinfo.com/cricketers/aaron-...              5
# 345   https://www.espncricinfo.com/cricketers/aaron-...              5
# 784   https://www.espncricinfo.com/cricketers/aaron-...              5
# 1118  https://www.espncricinfo.com/cricketers/abdul-...              2
# 992   https://www.espncricinfo.com/cricketers/abdul-...              2
# 119   https://www.espncricinfo.com/cricketers/abhije...              1
# 1023  https://www.espncricinfo.com/cricketers/abhina...              7
# 728   https://www.espncricinfo.com/cricketers/abhina...              7
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 440      109.426           0              0             0.000000
# 708      109.426          11             48            82.758621
# 518      109.426           0              0             0.000000
# 345      109.426           1              4            28.571429
# 784      109.426           1              6            85.714286
# 1118      33.330           0              0             0.000000
# 992       33.330           0              0                  NaN
# 119       50.000           1              4           100.000000
# 1023     104.930           0              0             0.000000
# 728      104.930           2              8            66.666667
#
#       Average_Boundary_Percentage  total_runs  batting_average  total_balls  \
# 440                     39.408867          86        17.200000           61
# 708                     39.408867          86        17.200000           61
# 518                     39.408867          86        17.200000           61
# 345                     39.408867          86        17.200000           61
# 784                     39.408867          86        17.200000           61
# 1118                     0.000000           4         2.000000            7
# 992                      0.000000           4         2.000000            7
# 119                    100.000000           4         4.000000            8
# 1023                    47.678110         108        15.428571           75
# 728                     47.678110         108        15.428571           75
#
#       innings_played  balls_avg
# 440                5  12.200000
# 708                5  12.200000
# 518                5  12.200000
# 345                5  12.200000
# 784                5  12.200000
# 1118               2   3.500000
# 992                2   3.500000
# 119                1   8.000000
# 1023               7  10.714286
# 728                7  10.714286

# %%
# Merge df2 with df to add the balls_avg column
df2 = df2.merge(df[['batsmanName', 'balls_avg']], on='batsmanName', how='left')

# Display the updated df2
print(df2)
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 0          Aaron Finch              5     109.426
# 1          Aaron Finch              5     109.426
# 2          Aaron Finch              5     109.426
# 3          Aaron Finch              5     109.426
# 4          Aaron Finch              5     109.426
# ...                ...            ...         ...
# 1171  Yashasvi Jaiswal             10     111.950
# 1172  Yashasvi Jaiswal             10     111.950
# 1173  Yashasvi Jaiswal             10     111.950
# 1174  Yuzvendra Chahal              2      31.250
# 1175  Yuzvendra Chahal              2      31.250
#
#       Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                       39.408867          86             17.2       12.2
# 1                       39.408867          86             17.2       12.2
# 2                       39.408867          86             17.2       12.2
# 3                       39.408867          86             17.2       12.2
# 4                       39.408867          86             17.2       12.2
# ...                           ...         ...              ...        ...
# 1171                    47.971507         258             25.8       19.4
# 1172                    47.971507         258             25.8       19.4
# 1173                    47.971507         258             25.8       19.4
# 1174                     0.000000           5              2.5        4.0
# 1175                     0.000000           5              2.5        4.0
#
# [1176 rows x 7 columns]

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#             batsmanName  inning_batted  Average_SR  \
# 0           Aaron Finch              5  109.426000
# 5           Abdul Samad              2   33.330000
# 7        Abhijeet Tomar              1   50.000000
# 8       Abhinav Manohar              7  104.930000
# 15      Abhishek Sharma             14  112.892857
# ...                 ...            ...         ...
# 1145  Washington Sundar              7  127.694286
# 1152  Wriddhiman Saha †             11  100.744545
# 1163         Yash Dayal              1    0.000000
# 1164   Yashasvi Jaiswal             10  111.950000
# 1174   Yuzvendra Chahal              2   31.250000
#
#       Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                       39.408867          86        17.200000  12.200000
# 5                        0.000000           4         2.000000   3.500000
# 7                      100.000000           4         4.000000   8.000000
# 8                       47.678110         108        15.428571  10.714286
# 15                      55.777865         426        30.428571  22.857143
# ...                           ...         ...              ...        ...
# 1145                    24.888889         101        14.428571   9.857143
# 1152                    62.355482         317        28.818182  23.545455
# 1163                          NaN           0         0.000000   1.000000
# 1164                    47.971507         258        25.800000  19.400000
# 1174                     0.000000           5         2.500000   4.000000
#
# [184 rows x 7 columns]

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 35) &
    (df2['Average_SR'] > 125) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 20)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#         batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0      David Warner             12  125.515833                    60.034301
# 1       Jos Buttler             17  128.744118                    60.396760
# 2     Rajat Patidar              7  142.585714                    57.929591
# 3  Suryakumar Yadav              8  138.737500                    57.966489
#
#    total_runs  batting_average  balls_avg
# 0         432        36.000000  23.916667
# 1         863        50.764706  34.058824
# 2         333        47.571429  31.142857
# 3         303        37.875000  26.000000

# %%
combined_df = pd.concat([filtered_df2, selected_players])
combined_df.to_csv('selected_players.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %% [markdown]
# # Filter criteria: (typically for lower order)
# # Batting Average > 25
# # Strike Rate > 130
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 12
# # Innings Bowled > 1

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 25) &
    (df2['Average_SR'] > 130) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 12)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2.to_csv('temp.csv', index=False)
filtered_df2
# Out:
#          batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0      Aiden Markram             12  131.062500                    46.137827
# 1      Andre Russell             12  143.687500                    70.734447
# 2       David Miller             16  136.240625                    46.507874
# 3       Deepak Hooda             14  134.700714                    51.470344
# 4   Liam Livingstone             14  167.060714                    57.456103
# 5     Rahul Tripathi             14  138.482857                    66.860644
# 6      Rajat Patidar              7  142.585714                    57.929591
# 7  Rishabh Pant (c)†             13  161.488462                    62.112634
# 8  Sanju Samson (c)†             17  148.932941                    69.300957
# 9   Suryakumar Yadav              8  138.737500                    57.966489
#
#    total_runs  batting_average  balls_avg
# 0         381        31.750000  22.833333
# 1         335        27.916667  16.000000
# 2         481        30.062500  21.062500
# 3         451        32.214286  23.571429
# 4         437        31.214286  17.142857
# 5         413        29.500000  18.642857
# 6         333        47.571429  31.142857
# 7         340        26.153846  17.230769
# 8         458        26.941176  18.352941
# 9         303        37.875000  26.000000
