# %%
import pandas as pd

# %% [markdown]
# # Filter criteria: (typically for openers)
# # 1. Batting Average > 30
# # 2. Strike Rate > 140
# # 3. Innings Batted >= 3
# # 4. Boundary % > 50

# %%
file_path = "batting.csv"  
df = pd.read_csv(file_path)
print(df.head())
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 0     Abhishek Sharma     2      5       3   0   0   40.00
# 1         Travis Head     0      1      11   0   0    0.00
# 2      Rahul Tripathi     9     13      21   1   0   69.23
# 3       Aiden Markram    20     23      41   3   0   86.95
# 4  Nitish Kumar Reddy    13     10      14   1   1  130.00
#
#                                          player_link   match_id
# 0  https://www.espncricinfo.com/cricketers/abhish...  scorecard
# 1  https://www.espncricinfo.com/cricketers/travis...  scorecard
# 2  https://www.espncricinfo.com/cricketers/rahul-...  scorecard
# 3  https://www.espncricinfo.com/cricketers/aiden-...  scorecard
# 4  https://www.espncricinfo.com/cricketers/nitish...  scorecard

# %%
df = df.drop(columns=['match_id'])
print(df.head())
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 0     Abhishek Sharma     2      5       3   0   0   40.00
# 1         Travis Head     0      1      11   0   0    0.00
# 2      Rahul Tripathi     9     13      21   1   0   69.23
# 3       Aiden Markram    20     23      41   3   0   86.95
# 4  Nitish Kumar Reddy    13     10      14   1   1  130.00
#
#                                          player_link
# 0  https://www.espncricinfo.com/cricketers/abhish...
# 1  https://www.espncricinfo.com/cricketers/travis...
# 2  https://www.espncricinfo.com/cricketers/rahul-...
# 3  https://www.espncricinfo.com/cricketers/aiden-...
# 4  https://www.espncricinfo.com/cricketers/nitish...

# %%
df = df.sort_values(by='batsmanName')

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link
# 428   https://www.espncricinfo.com/cricketers/abdul-...
# 585   https://www.espncricinfo.com/cricketers/abdul-...
# 21    https://www.espncricinfo.com/cricketers/abdul-...
# 773   https://www.espncricinfo.com/cricketers/abdul-...
# 1094  https://www.espncricinfo.com/cricketers/abdul-...
# ...                                                 ...
# 841   https://www.espncricinfo.com/cricketers/yashas...
# 25    https://www.espncricinfo.com/cricketers/yashas...
# 363   https://www.espncricinfo.com/cricketers/yashas...
# 292   https://www.espncricinfo.com/cricketers/yudhvi...
# 144   https://www.espncricinfo.com/cricketers/yudhvi...
#
# [1129 rows x 8 columns]

# %%
df.describe()
# Out:
#               runs        balls           4s           6s
# count  1129.000000  1129.000000  1129.000000  1129.000000
# mean     21.839681    14.503100     1.925598     1.116032
# std      22.599975    12.533651     2.329991     1.659328
# min       0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     5.000000     0.000000     0.000000
# 50%      15.000000    11.000000     1.000000     0.000000
# 75%      32.000000    21.000000     3.000000     2.000000
# max     124.000000    72.000000    14.000000    10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1129 entries, 428 to 144
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   batsmanName  1129 non-null   object
#  1   runs         1129 non-null   int64
#  2   balls        1129 non-null   int64
#  3   minutes      1129 non-null   object
#  4   4s           1129 non-null   int64
#  5   6s           1129 non-null   int64
#  6   SR           1129 non-null   object
#  7   player_link  1129 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 79.4+ KB

# %%
name_counts = df['batsmanName'].value_counts()

# Step 2: Add a new column to the DataFrame that shows how many times each player appears
df['inning_batted'] = df['batsmanName'].map(name_counts)

# Step 3: Display the updated DataFrame
print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
# [1129 rows x 9 columns]

# %%
print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
# [1129 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce')

df_cleaned = df[(df['SR'] != 0) & (df['SR'].notna())]

print(df_cleaned)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# 57         Abdul Samad    16     12      16   0   2  133.33
# ...                ...   ...    ...     ...  ..  ..     ...
# 988   Yashasvi Jaiswal     5      7      11   1   0   71.42
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# 57    https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 988   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
# [1017 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce').fillna(0)

df['Average_SR'] = df.groupby('batsmanName')['SR'].transform('mean')

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted  \
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR
# 428     150.1975
# 585     150.1975
# 21      150.1975
# 773     150.1975
# 1094    150.1975
# ...          ...
# 841     143.5480
# 25      143.5480
# 363     143.5480
# 292     150.0000
# 144     150.0000
#
# [1129 rows x 10 columns]

# %%
df['boundaries'] = df['4s'] + df['6s']

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted  \
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries
# 428     150.1975           2
# 585     150.1975           2
# 21      150.1975           0
# 773     150.1975           5
# 1094    150.1975           2
# ...          ...         ...
# 841     143.5480           0
# 25      143.5480           7
# 363     143.5480           9
# 292     150.0000           1
# 144     150.0000           2
#
# [1129 rows x 11 columns]

# %%
df['boundary_runs'] = (df['4s'] * 4) + (df['6s'] * 6)

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted  \
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs
# 428     150.1975           2             10
# 585     150.1975           2             10
# 21      150.1975           0              0
# 773     150.1975           5             20
# 1094    150.1975           2             10
# ...          ...         ...            ...
# 841     143.5480           0              0
# 25      143.5480           7             34
# 363     143.5480           9             40
# 292     150.0000           1              6
# 144     150.0000           2             10
#
# [1129 rows x 12 columns]

# %%
df['boundary_percentage'] = (df['boundary_runs'] / df['runs']) * 100

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted  \
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage
# 428     150.1975           2             10            52.631579
# 585     150.1975           2             10            76.923077
# 21      150.1975           0              0                  NaN
# 773     150.1975           5             20            80.000000
# 1094    150.1975           2             10            66.666667
# ...          ...         ...            ...                  ...
# 841     143.5480           0              0                  NaN
# 25      143.5480           7             34            80.952381
# 363     143.5480           9             40            59.701493
# 292     150.0000           1              6            85.714286
# 144     150.0000           2             10            71.428571
#
# [1129 rows x 13 columns]

# %%
df['Average_Boundary_Percentage'] = df.groupby('batsmanName')['boundary_percentage'].transform('mean')

df
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted  \
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 428     150.1975           2             10            52.631579
# 585     150.1975           2             10            76.923077
# 21      150.1975           0              0                  NaN
# 773     150.1975           5             20            80.000000
# 1094    150.1975           2             10            66.666667
# ...          ...         ...            ...                  ...
# 841     143.5480           0              0                  NaN
# 25      143.5480           7             34            80.952381
# 363     143.5480           9             40            59.701493
# 292     150.0000           1              6            85.714286
# 144     150.0000           2             10            71.428571
#
#       Average_Boundary_Percentage
# 428                     56.338876
# 585                     56.338876
# 21                      56.338876
# 773                     56.338876
# 1094                    56.338876
# ...                           ...
# 841                     77.918629
# 25                      77.918629
# 363                     77.918629
# 292                     78.571429
# 144                     78.571429
#
# [1129 rows x 14 columns]

# %%
df['total_runs'] = df.groupby('batsmanName')['runs'].transform('sum')
df['inning_batted'] = df.groupby('batsmanName')['inning_batted'].transform('count')

# Step 2: Calculate batting average for each player and add it to the DataFrame
df['batting_average'] = df['total_runs'] / df['inning_batted']

# Step 3: Display the updated DataFrame with batting averages and other columns
print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 428        Abdul Samad    19     18      30   1   1  105.55
# 585        Abdul Samad    13      8      12   1   1  162.50
# 21         Abdul Samad     0      1       1   0   0    0.00
# 773        Abdul Samad    25     12       -   5   0  208.33
# 1094       Abdul Samad    15     11      20   1   1  136.36
# ...                ...   ...    ...     ...  ..  ..     ...
# 841   Yashasvi Jaiswal     0      2       1   0   0    0.00
# 25    Yashasvi Jaiswal    42     21      39   4   3  200.00
# 363   Yashasvi Jaiswal    67     40       -   7   2  167.50
# 292      Yudhvir Singh     7      7       7   0   1  100.00
# 144      Yudhvir Singh    14      7      11   1   1  200.00
#
#                                             player_link  inning_batted  \
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# ...                                                 ...            ...
# 841   https://www.espncricinfo.com/cricketers/yashas...             15
# 25    https://www.espncricinfo.com/cricketers/yashas...             15
# 363   https://www.espncricinfo.com/cricketers/yashas...             15
# 292   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 144   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 428     150.1975           2             10            52.631579
# 585     150.1975           2             10            76.923077
# 21      150.1975           0              0                  NaN
# 773     150.1975           5             20            80.000000
# 1094    150.1975           2             10            66.666667
# ...          ...         ...            ...                  ...
# 841     143.5480           0              0                  NaN
# 25      143.5480           7             34            80.952381
# 363     143.5480           9             40            59.701493
# 292     150.0000           1              6            85.714286
# 144     150.0000           2             10            71.428571
#
#       Average_Boundary_Percentage  total_runs  batting_average
# 428                     56.338876         182        15.166667
# 585                     56.338876         182        15.166667
# 21                      56.338876         182        15.166667
# 773                     56.338876         182        15.166667
# 1094                    56.338876         182        15.166667
# ...                           ...         ...              ...
# 841                     77.918629         435        29.000000
# 25                      77.918629         435        29.000000
# 363                     77.918629         435        29.000000
# 292                     78.571429          21        10.500000
# 144                     78.571429          21        10.500000
#
# [1129 rows x 16 columns]

# %%
df.to_csv('processed_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
columns_to_keep = ['batsmanName', 'inning_batted', 'Average_SR', 'Average_Boundary_Percentage', 'total_runs', 'batting_average']

# Create the new DataFrame with the specified columns
df2 = df[columns_to_keep]

# Display the new DataFrame
df2.head()
# Out:
#       batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 428   Abdul Samad             12    150.1975                    56.338876
# 585   Abdul Samad             12    150.1975                    56.338876
# 21    Abdul Samad             12    150.1975                    56.338876
# 773   Abdul Samad             12    150.1975                    56.338876
# 1094  Abdul Samad             12    150.1975                    56.338876
#
#       total_runs  batting_average
# 428          182        15.166667
# 585          182        15.166667
# 21           182        15.166667
# 773          182        15.166667
# 1094         182        15.166667

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 428        Abdul Samad             12  150.197500
# 634    Abhinav Manohar              2   53.570000
# 262    Abhishek Sharma             16  189.463125
# 131      Abishek Porel             11  155.187273
# 159    Abishek Porel †              1   66.660000
# ..                 ...            ...         ...
# 587  Washington Sundar              2    0.000000
# 482         Will Jacks              8  142.110000
# 954  Wriddhiman Saha †              9  106.727778
# 753   Yashasvi Jaiswal             15  143.548000
# 292      Yudhvir Singh              2  150.000000
#
#      Average_Boundary_Percentage  total_runs  batting_average
# 428                    56.338876         182        15.166667
# 634                    25.000000           9         4.500000
# 262                    68.058298         484        30.250000
# 131                    62.941972         325        29.545455
# 159                     0.000000           2         2.000000
# ..                           ...         ...              ...
# 587                          NaN           0         0.000000
# 482                    57.831142         230        28.750000
# 954                    52.729353         136        15.111111
# 753                    77.918629         435        29.000000
# 292                    78.571429          21        10.500000
#
# [182 rows x 6 columns]

# %%
df2.to_csv('final_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
# for openers
filtered_df2 = df2[
    (df2['batting_average'] > 30) &
    (df2['Average_SR'] >140) &
    (df2['inning_batted'] > 3) &
    (df2['Average_Boundary_Percentage'] > 50)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 0      Abhishek Sharma             16  189.463125
# 1   Heinrich Klaasen †             15  159.089333
# 2   Jake Fraser-McGurk              9  208.617778
# 3      Nicholas Pooran             13  157.315385
# 4          Phil Salt †             12  164.010000
# 5        Rajat Patidar             13  150.966154
# 6    Rishabh Pant (c)†             13  142.459231
# 7          Riyan Parag             14  141.670000
# 8         Sunil Narine             14  149.191429
# 9          Tilak Varma             13  140.728462
# 10         Travis Head             15  141.268667
# 11         Virat Kohli             15  155.596667
#
#     Average_Boundary_Percentage  total_runs  batting_average
# 0                     68.058298         484        30.250000
# 1                     55.197611         479        31.933333
# 2                     89.655196         330        36.666667
# 3                     65.041706         457        35.153846
# 4                     77.875875         435        36.250000
# 5                     58.482860         395        30.384615
# 6                     56.409786         446        34.307692
# 7                     59.160569         573        40.928571
# 8                     75.128654         488        34.857143
# 9                     56.651358         416        32.000000
# 10                    68.312439         567        37.800000
# 11                    60.864230         741        49.400000

# %%
selected_players = filtered_df2['batsmanName']
selected_players
# Out:
# 0        Abhishek Sharma
# 1     Heinrich Klaasen †
# 2     Jake Fraser-McGurk
# 3        Nicholas Pooran
# 4            Phil Salt †
# 5          Rajat Patidar
# 6      Rishabh Pant (c)†
# 7            Riyan Parag
# 8           Sunil Narine
# 9            Tilak Varma
# 10           Travis Head
# 11           Virat Kohli
# Name: batsmanName, dtype: object

# %% [markdown]
# # Filter criteria: (typically for middle order)
# # Batting Average > 40
# # Strike Rate > 125
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 20

# %%
df['total_balls'] = df.groupby('batsmanName')['balls'].transform('sum')

df['innings_played'] = df.groupby('batsmanName')['inning_batted'].transform('count')
df['balls_avg'] = df['total_balls'] / df['innings_played']
df.head(10)
# Out:
#       batsmanName  runs  balls minutes  4s  6s      SR  \
# 428   Abdul Samad    19     18      30   1   1  105.55
# 585   Abdul Samad    13      8      12   1   1  162.50
# 21    Abdul Samad     0      1       1   0   0    0.00
# 773   Abdul Samad    25     12       -   5   0  208.33
# 1094  Abdul Samad    15     11      20   1   1  136.36
# 57    Abdul Samad    16     12      16   0   2  133.33
# 951   Abdul Samad    29     14      28   3   1  207.14
# 268   Abdul Samad     3      4      11   0   0   75.00
# 494   Abdul Samad    10      6       7   0   1  166.66
# 669   Abdul Samad    37     10      16   4   3  370.00
#
#                                             player_link  inning_batted  \
# 428   https://www.espncricinfo.com/cricketers/abdul-...             12
# 585   https://www.espncricinfo.com/cricketers/abdul-...             12
# 21    https://www.espncricinfo.com/cricketers/abdul-...             12
# 773   https://www.espncricinfo.com/cricketers/abdul-...             12
# 1094  https://www.espncricinfo.com/cricketers/abdul-...             12
# 57    https://www.espncricinfo.com/cricketers/abdul-...             12
# 951   https://www.espncricinfo.com/cricketers/abdul-...             12
# 268   https://www.espncricinfo.com/cricketers/abdul-...             12
# 494   https://www.espncricinfo.com/cricketers/abdul-...             12
# 669   https://www.espncricinfo.com/cricketers/abdul-...             12
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 428     150.1975           2             10            52.631579
# 585     150.1975           2             10            76.923077
# 21      150.1975           0              0                  NaN
# 773     150.1975           5             20            80.000000
# 1094    150.1975           2             10            66.666667
# 57      150.1975           2             12            75.000000
# 951     150.1975           4             18            62.068966
# 268     150.1975           0              0             0.000000
# 494     150.1975           1              6            60.000000
# 669     150.1975           7             34            91.891892
#
#       Average_Boundary_Percentage  total_runs  batting_average  total_balls  \
# 428                     56.338876         182        15.166667          108
# 585                     56.338876         182        15.166667          108
# 21                      56.338876         182        15.166667          108
# 773                     56.338876         182        15.166667          108
# 1094                    56.338876         182        15.166667          108
# 57                      56.338876         182        15.166667          108
# 951                     56.338876         182        15.166667          108
# 268                     56.338876         182        15.166667          108
# 494                     56.338876         182        15.166667          108
# 669                     56.338876         182        15.166667          108
#
#       innings_played  balls_avg
# 428               12        9.0
# 585               12        9.0
# 21                12        9.0
# 773               12        9.0
# 1094              12        9.0
# 57                12        9.0
# 951               12        9.0
# 268               12        9.0
# 494               12        9.0
# 669               12        9.0

# %%
# Merge df2 with df to add the balls_avg column
df2 = df2.merge(df[['batsmanName', 'balls_avg']], on='batsmanName', how='left')

# Display the updated df2
print(df2)
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 0          Abdul Samad             12    150.1975
# 1          Abdul Samad             12    150.1975
# 2          Abdul Samad             12    150.1975
# 3          Abdul Samad             12    150.1975
# 4          Abdul Samad             12    150.1975
# ...                ...            ...         ...
# 1124  Yashasvi Jaiswal             15    143.5480
# 1125  Yashasvi Jaiswal             15    143.5480
# 1126  Yashasvi Jaiswal             15    143.5480
# 1127     Yudhvir Singh              2    150.0000
# 1128     Yudhvir Singh              2    150.0000
#
#       Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                       56.338876         182        15.166667        9.0
# 1                       56.338876         182        15.166667        9.0
# 2                       56.338876         182        15.166667        9.0
# 3                       56.338876         182        15.166667        9.0
# 4                       56.338876         182        15.166667        9.0
# ...                           ...         ...              ...        ...
# 1124                    77.918629         435        29.000000       18.6
# 1125                    77.918629         435        29.000000       18.6
# 1126                    77.918629         435        29.000000       18.6
# 1127                    78.571429          21        10.500000        7.0
# 1128                    78.571429          21        10.500000        7.0
#
# [1129 rows x 7 columns]

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#             batsmanName  inning_batted  Average_SR  \
# 0           Abdul Samad             12  150.197500
# 12      Abhinav Manohar              2   53.570000
# 14      Abhishek Sharma             16  189.463125
# 30        Abishek Porel             11  155.187273
# 41      Abishek Porel †              1   66.660000
# ...                 ...            ...         ...
# 1093  Washington Sundar              2    0.000000
# 1095         Will Jacks              8  142.110000
# 1103  Wriddhiman Saha †              9  106.727778
# 1112   Yashasvi Jaiswal             15  143.548000
# 1127      Yudhvir Singh              2  150.000000
#
#       Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                       56.338876         182        15.166667   9.000000
# 12                      25.000000           9         4.500000   8.000000
# 14                      68.058298         484        30.250000  14.812500
# 30                      62.941972         325        29.545455  18.363636
# 41                       0.000000           2         2.000000   3.000000
# ...                           ...         ...              ...        ...
# 1093                          NaN           0         0.000000   0.500000
# 1095                    57.831142         230        28.750000  16.375000
# 1103                    52.729353         136        15.111111  12.777778
# 1112                    77.918629         435        29.000000  18.600000
# 1127                    78.571429          21        10.500000   7.000000
#
# [182 rows x 7 columns]

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 35) &
    (df2['Average_SR'] > 125) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 20)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#          batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0      KL Rahul (c)†             12  133.205000                    55.033912
# 1        Riyan Parag             14  141.670000                    59.160569
# 2      Sai Sudharsan             12  133.021667                    49.238810
# 3  Sanju Samson (c)†             15  131.002000                    59.303716
# 4   Shubman Gill (c)             12  128.738333                    53.002629
# 5        Virat Kohli             15  155.596667                    60.864230
#
#    total_runs  batting_average  balls_avg
# 0         500        41.666667  30.833333
# 1         573        40.928571  27.428571
# 2         527        43.916667  31.083333
# 3         531        35.400000  23.066667
# 4         426        35.500000  24.083333
# 5         741        49.400000  31.933333

# %%
combined_df = pd.concat([filtered_df2, selected_players])
combined_df.to_csv('selected_players.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %% [markdown]
# # Filter criteria: (typically for lower order)
# # Batting Average > 25
# # Strike Rate > 130
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 12
# # Innings Bowled > 1

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 25) &
    (df2['Average_SR'] > 130) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 12)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2.to_csv('temp.csv', index=False)
filtered_df2
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 0      Abhishek Sharma             16  189.463125
# 1        Abishek Porel             11  155.187273
# 2     Dinesh Karthik †              9  171.095556
# 3   Faf du Plessis (c)             15  149.500000
# 4   Heinrich Klaasen †             15  159.089333
# 5   Jake Fraser-McGurk              9  208.617778
# 6       Jonny Bairstow              9  146.812222
# 7        KL Rahul (c)†             12  133.205000
# 8      Nicholas Pooran             13  157.315385
# 9          Phil Salt †             12  164.010000
# 10      Rahul Tripathi              6  139.155000
# 11       Rajat Patidar             13  150.966154
# 12       Rilee Rossouw              8  138.832500
# 13   Rishabh Pant (c)†             13  142.459231
# 14         Riyan Parag             14  141.670000
# 15       Sai Sudharsan             12  133.021667
# 16   Sanju Samson (c)†             15  131.002000
# 17      Shashank Singh             14  131.057143
# 18    Shreyas Iyer (c)             14  147.632857
# 19        Sunil Narine             14  149.191429
# 20         Tilak Varma             13  140.728462
# 21         Travis Head             15  141.268667
# 22      Tristan Stubbs             13  160.974615
# 23      Venkatesh Iyer             13  155.910769
# 24         Virat Kohli             15  155.596667
# 25          Will Jacks              8  142.110000
# 26    Yashasvi Jaiswal             15  143.548000
#
#     Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                     68.058298         484        30.250000  14.812500
# 1                     62.941972         325        29.545455  18.363636
# 2                     69.533611         236        26.222222  13.555556
# 3                     67.969884         438        29.200000  18.066667
# 4                     55.197611         479        31.933333  18.666667
# 5                     89.655196         330        36.666667  15.666667
# 6                     71.299616         257        28.555556  17.444444
# 7                     55.033912         500        41.666667  30.833333
# 8                     65.041706         457        35.153846  19.923077
# 9                     77.875875         435        36.250000  19.916667
# 10                    57.326872         165        27.500000  19.166667
# 11                    58.482860         395        30.384615  17.153846
# 12                    68.249861         211        26.375000  14.500000
# 13                    56.409786         446        34.307692  22.076923
# 14                    59.160569         573        40.928571  27.428571
# 15                    49.238810         527        43.916667  31.083333
# 16                    59.303716         531        35.400000  23.066667
# 17                    52.473983         354        25.285714  15.357143
# 18                    63.610683         351        25.071429  17.071429
# 19                    75.128654         488        34.857143  19.285714
# 20                    56.651358         416        32.000000  21.384615
# 21                    68.312439         567        37.800000  19.733333
# 22                    46.071470         378        29.076923  15.230769
# 23                    57.453914         370        28.461538  17.923077
# 24                    60.864230         741        49.400000  31.933333
# 25                    57.831142         230        28.750000  16.375000
# 26                    77.918629         435        29.000000  18.600000
