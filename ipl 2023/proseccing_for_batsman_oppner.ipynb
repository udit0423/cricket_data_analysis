# %%
import pandas as pd

# %% [markdown]
# # Filter criteria: (typically for openers)
# # 1. Batting Average > 30
# # 2. Strike Rate > 140
# # 3. Innings Batted >= 3
# # 4. Boundary % > 50

# %%
file_path = "batting.csv"  
df = pd.read_csv(file_path)
print(df.head())
# Out:
#          batsmanName  runs  balls minutes  4s  6s      SR  \
# 0  Wriddhiman Saha †    54     39      63   5   1  138.46
# 1       Shubman Gill    39     20      34   7   0  195.00
# 2      Sai Sudharsan    96     47      58   8   6  204.25
# 3  Hardik Pandya (c)    21     12      32   0   2  175.00
# 4        Rashid Khan     0      2       2   0   0    0.00
#
#                                          player_link   match_id
# 0  https://www.espncricinfo.com/cricketers/wriddh...  scorecard
# 1  https://www.espncricinfo.com/cricketers/shubma...  scorecard
# 2  https://www.espncricinfo.com/cricketers/sai-su...  scorecard
# 3  https://www.espncricinfo.com/cricketers/hardik...  scorecard
# 4  https://www.espncricinfo.com/cricketers/rashid...  scorecard

# %%
df = df.drop(columns=['match_id'])
print(df.head())
# Out:
#          batsmanName  runs  balls minutes  4s  6s      SR  \
# 0  Wriddhiman Saha †    54     39      63   5   1  138.46
# 1       Shubman Gill    39     20      34   7   0  195.00
# 2      Sai Sudharsan    96     47      58   8   6  204.25
# 3  Hardik Pandya (c)    21     12      32   0   2  175.00
# 4        Rashid Khan     0      2       2   0   0    0.00
#
#                                          player_link
# 0  https://www.espncricinfo.com/cricketers/wriddh...
# 1  https://www.espncricinfo.com/cricketers/shubma...
# 2  https://www.espncricinfo.com/cricketers/sai-su...
# 3  https://www.espncricinfo.com/cricketers/hardik...
# 4  https://www.espncricinfo.com/cricketers/rashid...

# %%
df = df.sort_values(by='batsmanName')

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link
# 667   https://www.espncricinfo.com/cricketers/abdul-...
# 352   https://www.espncricinfo.com/cricketers/abdul-...
# 256   https://www.espncricinfo.com/cricketers/abdul-...
# 194   https://www.espncricinfo.com/cricketers/abdul-...
# 778   https://www.espncricinfo.com/cricketers/abdul-...
# ...                                                 ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...
# 564   https://www.espncricinfo.com/cricketers/yashas...
# 394   https://www.espncricinfo.com/cricketers/yashas...
# 841   https://www.espncricinfo.com/cricketers/yudhvi...
# 757   https://www.espncricinfo.com/cricketers/yudhvi...
#
# [1181 rows x 8 columns]

# %%
df.describe()
# Out:
#               runs        balls           4s           6s
# count  1181.000000  1181.000000  1181.000000  1181.000000
# mean     20.684166    14.595258     1.840813     0.951736
# std      22.940697    13.523693     2.477025     1.573146
# min       0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     4.000000     0.000000     0.000000
# 50%      12.000000    10.000000     1.000000     0.000000
# 75%      30.000000    21.000000     3.000000     1.000000
# max     129.000000    66.000000    16.000000    10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1181 entries, 667 to 757
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   batsmanName  1181 non-null   object
#  1   runs         1181 non-null   int64
#  2   balls        1181 non-null   int64
#  3   minutes      1181 non-null   object
#  4   4s           1181 non-null   int64
#  5   6s           1181 non-null   int64
#  6   SR           1181 non-null   object
#  7   player_link  1181 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 83.0+ KB

# %%
name_counts = df['batsmanName'].value_counts()

# Step 2: Add a new column to the DataFrame that shows how many times each player appears
df['inning_batted'] = df['batsmanName'].map(name_counts)

# Step 3: Display the updated DataFrame
print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
# [1181 rows x 9 columns]

# %%
print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
# [1181 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce')

df_cleaned = df[(df['SR'] != 0) & (df['SR'].notna())]

print(df_cleaned)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 133   Yashasvi Jaiswal    50     36      72   8   0  138.88
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 133   https://www.espncricinfo.com/cricketers/yashas...             14
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
# [1049 rows x 9 columns]

# %%
df['SR'] = pd.to_numeric(df['SR'], errors='coerce').fillna(0)

df['Average_SR'] = df.groupby('batsmanName')['SR'].transform('mean')

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted  \
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR
# 667   100.000000
# 352   144.896250
# 256   144.896250
# 194   144.896250
# 778   144.896250
# ...          ...
# 1113  136.939286
# 564   136.939286
# 394   136.939286
# 841    50.000000
# 757    50.000000
#
# [1181 rows x 10 columns]

# %%
df['boundaries'] = df['4s'] + df['6s']

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted  \
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries
# 667   100.000000           0
# 352   144.896250           2
# 256   144.896250           5
# 194   144.896250           1
# 778   144.896250           1
# ...          ...         ...
# 1113  136.939286           9
# 564   136.939286          12
# 394   136.939286           2
# 841    50.000000           0
# 757    50.000000           0
#
# [1181 rows x 11 columns]

# %%
df['boundary_runs'] = (df['4s'] * 4) + (df['6s'] * 6)

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted  \
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs
# 667   100.000000           0              0
# 352   144.896250           2             12
# 256   144.896250           5             28
# 194   144.896250           1              4
# 778   144.896250           1              4
# ...          ...         ...            ...
# 1113  136.939286           9             36
# 564   136.939286          12             56
# 394   136.939286           2             10
# 841    50.000000           0              0
# 757    50.000000           0              0
#
# [1181 rows x 12 columns]

# %%
df['boundary_percentage'] = (df['boundary_runs'] / df['runs']) * 100

print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted  \
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage
# 667   100.000000           0              0             0.000000
# 352   144.896250           2             12            70.588235
# 256   144.896250           5             28            75.675676
# 194   144.896250           1              4           100.000000
# 778   144.896250           1              4            44.444444
# ...          ...         ...            ...                  ...
# 1113  136.939286           9             36            66.666667
# 564   136.939286          12             56            72.727273
# 394   136.939286           2             10            71.428571
# 841    50.000000           0              0                  NaN
# 757    50.000000           0              0             0.000000
#
# [1181 rows x 13 columns]

# %%
df['Average_Boundary_Percentage'] = df.groupby('batsmanName')['boundary_percentage'].transform('mean')

df
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted  \
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 667   100.000000           0              0             0.000000
# 352   144.896250           2             12            70.588235
# 256   144.896250           5             28            75.675676
# 194   144.896250           1              4           100.000000
# 778   144.896250           1              4            44.444444
# ...          ...         ...            ...                  ...
# 1113  136.939286           9             36            66.666667
# 564   136.939286          12             56            72.727273
# 394   136.939286           2             10            71.428571
# 841    50.000000           0              0                  NaN
# 757    50.000000           0              0             0.000000
#
#       Average_Boundary_Percentage
# 667                      0.000000
# 352                     65.616818
# 256                     65.616818
# 194                     65.616818
# 778                     65.616818
# ...                           ...
# 1113                    70.933030
# 564                     70.933030
# 394                     70.933030
# 841                      0.000000
# 757                      0.000000
#
# [1181 rows x 14 columns]

# %%
df['total_runs'] = df.groupby('batsmanName')['runs'].transform('sum')
df['inning_batted'] = df.groupby('batsmanName')['inning_batted'].transform('count')

# Step 2: Calculate batting average for each player and add it to the DataFrame
df['batting_average'] = df['total_runs'] / df['inning_batted']

# Step 3: Display the updated DataFrame with batting averages and other columns
print(df)
# Out:
#            batsmanName  runs  balls minutes  4s  6s      SR  \
# 667       Abdul Basith     1      1       2   0   0  100.00
# 352        Abdul Samad    17      7      17   0   2  242.85
# 256        Abdul Samad    37     25      41   1   4  148.00
# 194        Abdul Samad     4      3       5   1   0  133.33
# 778        Abdul Samad     9     12      34   1   0   75.00
# ...                ...   ...    ...     ...  ..  ..     ...
# 1113  Yashasvi Jaiswal    54     37      63   9   0  145.94
# 564   Yashasvi Jaiswal    77     43      67   8   4  179.06
# 394   Yashasvi Jaiswal    14     11      31   1   1  127.27
# 841      Yudhvir Singh     0      1       3   0   0    0.00
# 757      Yudhvir Singh     1      1       2   0   0  100.00
#
#                                             player_link  inning_batted  \
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# ...                                                 ...            ...
# 1113  https://www.espncricinfo.com/cricketers/yashas...             14
# 564   https://www.espncricinfo.com/cricketers/yashas...             14
# 394   https://www.espncricinfo.com/cricketers/yashas...             14
# 841   https://www.espncricinfo.com/cricketers/yudhvi...              2
# 757   https://www.espncricinfo.com/cricketers/yudhvi...              2
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 667   100.000000           0              0             0.000000
# 352   144.896250           2             12            70.588235
# 256   144.896250           5             28            75.675676
# 194   144.896250           1              4           100.000000
# 778   144.896250           1              4            44.444444
# ...          ...         ...            ...                  ...
# 1113  136.939286           9             36            66.666667
# 564   136.939286          12             56            72.727273
# 394   136.939286           2             10            71.428571
# 841    50.000000           0              0                  NaN
# 757    50.000000           0              0             0.000000
#
#       Average_Boundary_Percentage  total_runs  batting_average
# 667                      0.000000           1         1.000000
# 352                     65.616818         169        21.125000
# 256                     65.616818         169        21.125000
# 194                     65.616818         169        21.125000
# 778                     65.616818         169        21.125000
# ...                           ...         ...              ...
# 1113                    70.933030         625        44.642857
# 564                     70.933030         625        44.642857
# 394                     70.933030         625        44.642857
# 841                      0.000000           1         0.500000
# 757                      0.000000           1         0.500000
#
# [1181 rows x 16 columns]

# %%
df.to_csv('processed_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
columns_to_keep = ['batsmanName', 'inning_batted', 'Average_SR', 'Average_Boundary_Percentage', 'total_runs', 'batting_average']

# Create the new DataFrame with the specified columns
df2 = df[columns_to_keep]

# Display the new DataFrame
df2.head()
# Out:
#       batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 667  Abdul Basith              1   100.00000                     0.000000
# 352   Abdul Samad              8   144.89625                    65.616818
# 256   Abdul Samad              8   144.89625                    65.616818
# 194   Abdul Samad              8   144.89625                    65.616818
# 778   Abdul Samad              8   144.89625                    65.616818
#
#      total_runs  batting_average
# 667           1            1.000
# 352         169           21.125
# 256         169           21.125
# 194         169           21.125
# 778         169           21.125

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#             batsmanName  inning_batted  Average_SR  \
# 667        Abdul Basith              1  100.000000
# 352         Abdul Samad              8  144.896250
# 805     Abhinav Manohar              6  131.355000
# 702     Abhishek Sharma             11  111.402727
# 866     Abishek Porel †              4   88.852500
# ...                 ...            ...         ...
# 798       Wayne Parnell              1   40.000000
# 1174  Wriddhiman Saha †             17  107.431765
# 864          Yash Dhull              3   53.886667
# 809    Yashasvi Jaiswal             14  136.939286
# 841       Yudhvir Singh              2   50.000000
#
#       Average_Boundary_Percentage  total_runs  batting_average
# 667                      0.000000           1         1.000000
# 352                     65.616818         169        21.125000
# 805                     41.147741         114        19.000000
# 702                     52.103458         226        20.545455
# 866                     29.285714          33         8.250000
# ...                           ...         ...              ...
# 798                      0.000000           2         2.000000
# 1174                    58.950648         371        21.823529
# 864                     10.256410          16         5.333333
# 809                     70.933030         625        44.642857
# 841                      0.000000           1         0.500000
#
# [193 rows x 6 columns]

# %%
df2.to_csv('final_batting_stats.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
# for openers
filtered_df2 = df2[
    (df2['batting_average'] > 30) &
    (df2['Average_SR'] >140) &
    (df2['inning_batted'] > 3) &
    (df2['Average_Boundary_Percentage'] > 50)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#           batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0  Faf du Plessis (c)             11  153.735455                    62.737770
# 1  Heinrich Klaasen †             11  182.172727                    61.097009
# 2           Jason Roy              8  145.907500                    72.209325
# 3         Rinku Singh             14  144.611429                    55.986462
# 4    Suryakumar Yadav             15  154.372000                    57.794447
# 5         Tilak Varma             11  158.990909                    57.368581
# 6       Vijay Shankar             10  149.695000                    60.114255
#
#    total_runs  batting_average
# 0         567        51.545455
# 1         448        40.727273
# 2         285        35.625000
# 3         474        33.857143
# 4         562        37.466667
# 5         343        31.181818
# 6         301        30.100000

# %%
selected_players = filtered_df2['batsmanName']
selected_players
# Out:
# 0    Faf du Plessis (c)
# 1    Heinrich Klaasen †
# 2             Jason Roy
# 3           Rinku Singh
# 4      Suryakumar Yadav
# 5           Tilak Varma
# 6         Vijay Shankar
# Name: batsmanName, dtype: object

# %% [markdown]
# # Filter criteria: (typically for middle order)
# # Batting Average > 40
# # Strike Rate > 125
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 20

# %%
df['total_balls'] = df.groupby('batsmanName')['balls'].transform('sum')

df['innings_played'] = df.groupby('batsmanName')['inning_batted'].transform('count')
df['balls_avg'] = df['total_balls'] / df['innings_played']
df.head(10)
# Out:
#           batsmanName  runs  balls minutes  4s  6s      SR  \
# 667      Abdul Basith     1      1       2   0   0  100.00
# 352       Abdul Samad    17      7      17   0   2  242.85
# 256       Abdul Samad    37     25      41   1   4  148.00
# 194       Abdul Samad     4      3       5   1   0  133.33
# 778       Abdul Samad     9     12      34   1   0   75.00
# 425       Abdul Samad    21     18      34   3   0  116.66
# 1126      Abdul Samad    32     32      51   2   1  100.00
# 1019      Abdul Samad    21     10      11   1   2  210.00
# 523       Abdul Samad    28     21      21   1   2  133.33
# 805   Abhinav Manohar    27     13      17   0   3  207.69
#
#                                             player_link  inning_batted  \
# 667   https://www.espncricinfo.com/cricketers/abdul-...              1
# 352   https://www.espncricinfo.com/cricketers/abdul-...              8
# 256   https://www.espncricinfo.com/cricketers/abdul-...              8
# 194   https://www.espncricinfo.com/cricketers/abdul-...              8
# 778   https://www.espncricinfo.com/cricketers/abdul-...              8
# 425   https://www.espncricinfo.com/cricketers/abdul-...              8
# 1126  https://www.espncricinfo.com/cricketers/abdul-...              8
# 1019  https://www.espncricinfo.com/cricketers/abdul-...              8
# 523   https://www.espncricinfo.com/cricketers/abdul-...              8
# 805   https://www.espncricinfo.com/cricketers/abhina...              6
#
#       Average_SR  boundaries  boundary_runs  boundary_percentage  \
# 667    100.00000           0              0             0.000000
# 352    144.89625           2             12            70.588235
# 256    144.89625           5             28            75.675676
# 194    144.89625           1              4           100.000000
# 778    144.89625           1              4            44.444444
# 425    144.89625           3             12            57.142857
# 1126   144.89625           3             14            43.750000
# 1019   144.89625           3             16            76.190476
# 523    144.89625           3             16            57.142857
# 805    131.35500           3             18            66.666667
#
#       Average_Boundary_Percentage  total_runs  batting_average  total_balls  \
# 667                      0.000000           1            1.000            1
# 352                     65.616818         169           21.125          128
# 256                     65.616818         169           21.125          128
# 194                     65.616818         169           21.125          128
# 778                     65.616818         169           21.125          128
# 425                     65.616818         169           21.125          128
# 1126                    65.616818         169           21.125          128
# 1019                    65.616818         169           21.125          128
# 523                     65.616818         169           21.125          128
# 805                     41.147741         114           19.000           83
#
#       innings_played  balls_avg
# 667                1   1.000000
# 352                8  16.000000
# 256                8  16.000000
# 194                8  16.000000
# 778                8  16.000000
# 425                8  16.000000
# 1126               8  16.000000
# 1019               8  16.000000
# 523                8  16.000000
# 805                6  13.833333

# %%
# Merge df2 with df to add the balls_avg column
df2 = df2.merge(df[['batsmanName', 'balls_avg']], on='batsmanName', how='left')

# Display the updated df2
print(df2)
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 0         Abdul Basith              1  100.000000
# 1          Abdul Samad              8  144.896250
# 2          Abdul Samad              8  144.896250
# 3          Abdul Samad              8  144.896250
# 4          Abdul Samad              8  144.896250
# ...                ...            ...         ...
# 1176  Yashasvi Jaiswal             14  136.939286
# 1177  Yashasvi Jaiswal             14  136.939286
# 1178  Yashasvi Jaiswal             14  136.939286
# 1179     Yudhvir Singh              2   50.000000
# 1180     Yudhvir Singh              2   50.000000
#
#       Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                        0.000000           1         1.000000   1.000000
# 1                       65.616818         169        21.125000  16.000000
# 2                       65.616818         169        21.125000  16.000000
# 3                       65.616818         169        21.125000  16.000000
# 4                       65.616818         169        21.125000  16.000000
# ...                           ...         ...              ...        ...
# 1176                    70.933030         625        44.642857  27.285714
# 1177                    70.933030         625        44.642857  27.285714
# 1178                    70.933030         625        44.642857  27.285714
# 1179                     0.000000           1         0.500000   1.000000
# 1180                     0.000000           1         0.500000   1.000000
#
# [1181 rows x 7 columns]

# %%
# Removing duplicate rows from the DataFrame
df2 = df2.drop_duplicates()

# Display the updated DataFrame
print(df2)
# Out:
#             batsmanName  inning_batted  Average_SR  \
# 0          Abdul Basith              1  100.000000
# 1           Abdul Samad              8  144.896250
# 9       Abhinav Manohar              6  131.355000
# 15      Abhishek Sharma             11  111.402727
# 26      Abishek Porel †              4   88.852500
# ...                 ...            ...         ...
# 1144      Wayne Parnell              1   40.000000
# 1145  Wriddhiman Saha †             17  107.431765
# 1162         Yash Dhull              3   53.886667
# 1165   Yashasvi Jaiswal             14  136.939286
# 1179      Yudhvir Singh              2   50.000000
#
#       Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                        0.000000           1         1.000000   1.000000
# 1                       65.616818         169        21.125000  16.000000
# 9                       41.147741         114        19.000000  13.833333
# 15                      52.103458         226        20.545455  14.272727
# 26                      29.285714          33         8.250000   7.750000
# ...                           ...         ...              ...        ...
# 1144                     0.000000           2         2.000000   5.000000
# 1145                    58.950648         371        21.823529  16.882353
# 1162                    10.256410          16         5.333333   7.666667
# 1165                    70.933030         625        44.642857  27.285714
# 1179                     0.000000           1         0.500000   1.000000
#
# [193 rows x 7 columns]

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 35) &
    (df2['Average_SR'] > 125) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 20)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2
# Out:
#           batsmanName  inning_batted  Average_SR  Average_Boundary_Percentage  \
# 0  Faf du Plessis (c)             11  153.735455                    62.737770
# 1  Heinrich Klaasen †             11  182.172727                    61.097009
# 2           Jason Roy              8  145.907500                    72.209325
# 3   Quinton de Kock †              4  133.430000                    61.410099
# 4     Ruturaj Gaikwad             15  139.366667                    55.831800
# 5       Sai Sudharsan              8  133.975000                    52.777908
# 6        Shubman Gill             17  136.261765                    58.190414
# 7    Suryakumar Yadav             15  154.372000                    57.794447
# 8         Virat Kohli             11  126.054545                    49.268930
# 9    Yashasvi Jaiswal             14  136.939286                    70.933030
#
#    total_runs  batting_average  balls_avg
# 0         567        51.545455  33.909091
# 1         448        40.727273  23.000000
# 2         285        35.625000  23.500000
# 3         143        35.750000  25.500000
# 4         590        39.333333  26.666667
# 5         362        45.250000  32.000000
# 6         890        52.352941  33.176471
# 7         562        37.466667  20.600000
# 8         526        47.818182  33.818182
# 9         625        44.642857  27.285714

# %%
combined_df = pd.concat([filtered_df2, selected_players])
combined_df.to_csv('selected_players.csv', index=False)
# Out:
# c:\Users\kiran\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %% [markdown]
# # Filter criteria: (typically for lower order)
# # Batting Average > 25
# # Strike Rate > 130
# # Innings Batted > 3
# # Average balls faced by the batter in an innings> 12
# # Innings Bowled > 1

# %%
filtered_df2 = df2[
    (df2['batting_average'] > 25) &
    (df2['Average_SR'] > 130) &
    (df2['inning_batted'] > 3) &
    (df2['balls_avg'] > 12)
]

filtered_df2.reset_index(drop=True, inplace=True)
filtered_df2.to_csv('temp.csv', index=False)
filtered_df2
# Out:
#            batsmanName  inning_batted  Average_SR  \
# 0       Ajinkya Rahane             11  161.448182
# 1        Atharva Taide              7  131.380000
# 2        Cameron Green             16  140.250000
# 3   Faf du Plessis (c)             11  153.735455
# 4        Glenn Maxwell             14  156.695714
# 5   Heinrich Klaasen †             11  182.172727
# 6            Jason Roy              8  145.907500
# 7     Liam Livingstone              9  130.135556
# 8      Nicholas Pooran              4  170.447500
# 9    Quinton de Kock †              4  133.430000
# 10         Rinku Singh             14  144.611429
# 11     Ruturaj Gaikwad             15  139.366667
# 12       Sai Sudharsan              8  133.975000
# 13         Shivam Dube             14  153.422143
# 14        Shubman Gill             17  136.261765
# 15    Suryakumar Yadav             15  154.372000
# 16         Tilak Varma             11  158.990909
# 17       Vijay Shankar             10  149.695000
# 18    Yashasvi Jaiswal             14  136.939286
#
#     Average_Boundary_Percentage  total_runs  batting_average  balls_avg
# 0                     47.188619         326        29.636364  17.181818
# 1                     63.609049         186        26.571429  18.428571
# 2                     47.834033         452        28.250000  17.625000
# 3                     62.737770         567        51.545455  33.909091
# 4                     73.439447         400        28.571429  15.571429
# 5                     61.097009         448        40.727273  23.000000
# 6                     72.209325         285        35.625000  23.500000
# 7                     61.939116         279        31.000000  19.000000
# 8                     52.782132         113        28.250000  14.250000
# 9                     61.410099         143        35.750000  25.500000
# 10                    55.986462         474        33.857143  22.642857
# 11                    55.831800         590        39.333333  26.666667
# 12                    52.777908         362        45.250000  32.000000
# 13                    56.228640         418        29.857143  18.857143
# 14                    58.190414         890        52.352941  33.176471
# 15                    57.794447         562        37.466667  20.600000
# 16                    57.368581         343        31.181818  19.000000
# 17                    60.114255         301        30.100000  18.800000
# 18                    70.933030         625        44.642857  27.285714
